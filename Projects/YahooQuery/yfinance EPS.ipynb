# %%
from yahooquery import Ticker

aapl = Ticker('aapl')

aapl.summary_detail
# Out:
# {'aapl': {'maxAge': 1,
#   'priceHint': 2,
#   'previousClose': 148.48,
#   'open': 150.2,
#   'dayLow': 148.14,
#   'dayHigh': 149.5,
#   'regularMarketPreviousClose': 148.48,
#   'regularMarketOpen': 150.2,
#   'regularMarketDayLow': 148.14,
#   'regularMarketDayHigh': 149.5,
#   'dividendRate': 0.92,
#   'dividendYield': 0.0062,
#   'exDividendDate': '2023-02-09 18:00:00',
#   'payoutRatio': 0.1545,
#   'fiveYearAvgDividendYield': 0.96,
#   'beta': 1.277894,
#   'trailingPE': 25.174873,
#   'forwardPE': 22.534954,
#   'volume': 4560848,
#   'regularMarketVolume': 4560848,
#   'averageVolume': 75556261,
#   'averageVolume10days': 63647100,
#   'averageDailyVolume10Day': 63647100,
#   'bid': 148.74,
#   'ask': 148.63,
#   'bidSize': 1100,
#   'askSize': 900,
#   'marketCap': 2346071359488,
#   'fiftyTwoWeekLow': 124.17,
#   'fiftyTwoWeekHigh': 179.61,
#   'priceToSalesTrailing12Months': 6.0537996,
#   'fiftyDayAverage': 140.2488,
#   'twoHundredDayAverage': 147.30605,
# ...

# %%
# import pandas_datareader.data as web
# import yfinance as yf
# import datetime

# yf.pdr_override()

# start = datetime.datetime(1990, 1, 1)
# end = datetime.datetime.today()
# data_dict = {}
# for key in ["MSFT", "AAPL"]:
#     data_dict[key] = web.get_data_yahoo(key, start, end)
# data_dict[key]

# %%
import yfinance as yf
msft = yf.Ticker("MSFT")
msft
# Out:
# yfinance.Ticker object <MSFT>

# %%
# get all stock info (slow)
msft.info
# Out:
# {'regularMarketPrice': None, 'preMarketPrice': None, 'logo_url': ''}

# %%
# get historical market data
hist = msft.history(period="40y")
hist
# Out:
#                   Open        High         Low       Close      Volume  \
# Date
# 1986-03-13    0.055241    0.063365    0.055241    0.060657  1031788800
# 1986-03-14    0.060657    0.063907    0.060657    0.062823   308160000
# 1986-03-17    0.062823    0.064448    0.062823    0.063907   133171200
# 1986-03-18    0.063907    0.064448    0.061740    0.062281    67766400
# 1986-03-19    0.062281    0.062823    0.060657    0.061198    47894400
# ...                ...         ...         ...         ...         ...
# 2023-02-15  268.320007  270.730011  266.179993  269.320007    28962200
# 2023-02-16  264.019989  266.739990  261.899994  262.149994    29603600
# 2023-02-17  259.390015  260.089996  256.000000  258.059998    29979600
# 2023-02-21  254.479996  255.490005  251.589996  252.669998    28371400
# 2023-02-22  254.479996  254.330002  253.000000  253.600006     1976956
#
#             Dividends  Stock Splits
# Date
# 1986-03-13       0.00           0.0
# ...

# %%
# show actions (dividends, splits, capital gains)
msft.actions
# Out:
#             Dividends  Stock Splits
# Date
# 1987-09-21       0.00           2.0
# 1990-04-16       0.00           2.0
# 1991-06-27       0.00           1.5
# 1992-06-15       0.00           1.5
# 1994-05-23       0.00           2.0
# ...               ...           ...
# 2022-02-16       0.62           0.0
# 2022-05-18       0.62           0.0
# 2022-08-17       0.62           0.0
# 2022-11-16       0.68           0.0
# 2023-02-15       0.68           0.0
#
# [86 rows x 2 columns]

# %%
for key in dir(msft):
    try:
        print(key)
        print()
        print(getattr(msft, key))
    except:
        print(key, "not accessible")
        continue
# Out:
# __class__
#
# <class 'yfinance.ticker.Ticker'>
# __delattr__
#
# <method-wrapper '__delattr__' of Ticker object at 0x00000180D8849CA0>
# __dict__
#
# {'ticker': 'MSFT', 'session': None, '_history':                   Open        High         Low       Close      Volume  \
# Date
# 1986-03-13    0.055241    0.063365    0.055241    0.060657  1031788800
# 1986-03-14    0.060657    0.063907    0.060657    0.062823   308160000
# 1986-03-17    0.062823    0.064448    0.062823    0.063907   133171200
# 1986-03-18    0.063907    0.064448    0.061740    0.062281    67766400
# 1986-03-19    0.062281    0.062823    0.060657    0.061198    47894400
# ...                ...         ...         ...         ...         ...
# 2023-02-15  268.320007  270.730011  266.179993  269.320007    28962200
# 2023-02-16  264.019989  266.739990  261.899994  262.149994    29603600
# 2023-02-17  259.390015  260.089996  256.000000  258.059998    29979600
# ...

# %%
msft._earnings_history.dropna(subset = "EPS Estimate")
# Out:
#    Symbol                Company           Earnings Date  EPS Estimate  \
# 4    MSFT         Microsoft Corp   Apr 24, 2023, 6 AMEDT          2.23
# 5    MSFT  Microsoft Corporation  Jan 24, 2023, 11 AMEST          2.30
# 6    MSFT  Microsoft Corporation  Oct 25, 2022, 12 PMEDT          2.30
# 7    MSFT  Microsoft Corporation  Jul 26, 2022, 12 PMEDT          2.29
# 8    MSFT  Microsoft Corporation  Apr 26, 2022, 12 PMEDT          2.19
# ..    ...                    ...                     ...           ...
# 95   MSFT  Microsoft Corporation  Jul 18, 2000, 12 AMEDT          0.21
# 96   MSFT  Microsoft Corporation  Apr 20, 2000, 12 AMEDT          0.20
# 97   MSFT  Microsoft Corporation  Jan 18, 2000, 12 AMEST          0.21
# 98   MSFT  Microsoft Corporation  Oct 19, 1999, 12 AMEDT          0.17
# 99   MSFT  Microsoft Corporation  Jul 19, 1999, 12 AMEDT          0.18
#
#     Reported EPS Surprise(%)
# 4            NaN         NaN
# 5           2.32       +1.09
# ...

# %%
msft.mutualfund_holders.dropna()
# Out:
#                                               Holder     Shares Date Reported  \
# 0             Vanguard Total Stock Market Index Fund  222313847    2022-09-29
# 1                            Vanguard 500 Index Fund  169062762    2022-09-29
# 2                             SPDR S&P 500 ETF Trust   82250000    2022-12-30
# 3                            Fidelity 500 Index Fund   81679555    2022-12-30
# 4        Invesco ETF Tr-Invesco QQQ Tr, Series 1 ETF   76335623    2022-12-30
# 5                           iShares Core S&P 500 ETF   66940817    2022-12-30
# 6                         Vanguard Growth Index Fund   61426549    2022-09-29
# 7  Vanguard Institutional Index Fund-Institutiona...   54149972    2022-09-29
# 8                         Growth Fund Of America Inc   44491127    2022-12-30
# 9                 Select Sector SPDR Fund-Technology   34910084    2022-12-30
#
#     % Out        Value
# 0  0.0299  56365451275
# 1  0.0227  42864171542
# 2  0.0110  20853664447
# ...

# %%
msft.get_financials()
# Out:
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %%
yf.__version__
# Out:
# '0.1.72'

# %%
# !pip unistall yfinance
# !pip install yfinance==0.1.72
