# %%
import pandas as pd
import numpy as np

df = pd.read_excel("DataTransformation.xlsx", sheet_name = "Sheet2", header = 1)

df
# Out:
#     Questions  Respondents/ID Choices Choosen  code_choosen  Payment  \
# 0         1.0               1       A     NaN           NaN        2
# 1         NaN               1       B       B           0.0        4
# 2         2.0               1       A       A           1.0        2
# 3         NaN               1       B     NaN           NaN        3
# 4         3.0               1       A     NaN           NaN        2
# 5         NaN               1       B       B           0.0        0
# 6         4.0               1       A       A           1.0        0
# 7         NaN               1       B     NaN           NaN        1
# 8         5.0               1       A     NaN           NaN        0
# 9         NaN               1       B       B           0.0        1
# 10        6.0               1       A     NaN           NaN        4
# 11        NaN               1       B       B           0.0        4
# 12        7.0               1       A       A           1.0        3
# ...

# %%
df.dropna(subset=["code_choosen"])
# Out:
#     Questions  Respondents/ID Choices Choosen  code_choosen  Payment  \
# 1         NaN               1       B       B           0.0        4
# 2         2.0               1       A       A           1.0        2
# 5         NaN               1       B       B           0.0        0
# 6         4.0               1       A       A           1.0        0
# 9         NaN               1       B       B           0.0        1
# 11        NaN               1       B       B           0.0        4
# 12        7.0               1       A       A           1.0        3
# 14        8.0               1       A       A           1.0        2
# 17        NaN               1       B       B           0.0        0
# 19        NaN               1       B       B           0.0        3
# 20       11.0               1       A       A           1.0        4
# 22       12.0               1       A       A           1.0        1
# 25        NaN               1       B       B           0.0        4
# ...
