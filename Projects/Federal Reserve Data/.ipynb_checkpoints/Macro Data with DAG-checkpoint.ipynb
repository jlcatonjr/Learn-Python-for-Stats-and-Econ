# %%
# import datetime
import os
import pandas
import numpy as np
import matplotlib.pyplot as plt
from datlib.FRED import *
from datlib.plots import *
import pandas_datareader.data as web


#FRED.py
#. . . 
def bil_to_mil(series):
    return series* 10**3
# . . .
#fedProject.py
# . . .
data_codes  = {# Assets
               "Balance Sheet: Total Assets ($ Mil)": "WALCL",
               "Balance Sheet Securities, Prem-Disc, Repos, and Loans ($ Mil)": "WSRLL",
               "Balance Sheet: Securities Held Outright ($ Mil)": "WSHOSHO",
               ### breakdown of securities holdings ###
               "Balance Sheet: U.S. Treasuries Held Outright ($ Mil)":"WSHOTSL",
               "Balance Sheet: Federal Agency Debt Securities ($ Mil)" : "WSHOFADSL",
               "Balance Sheet: Mortgage-Backed Securities ($ Mil)": "WSHOMCB",
               # other forms of lending
               "Balance Sheet: Repos ($ Mil)": "WORAL",
               "Balance Sheet: Central Bank Liquidity Swaps ($ Mil)" : "SWPT",
               "Balance Sheet: Direct Lending ($ Mil)" : "WLCFLL",
               # unamortized value of securities held (due to changes in interest rates)
               "Balance Sheet: Unamortized Security Premiums ($ Mil)": "WUPSHO",
               # Liabilities
               "Balance Sheet: Total Liabilities ($ Mil)" : "WLTLECL",
               "Balance Sheet: Federal Reserve Notes Outstanding ($ Mil)" : "WLFN",
               "Balance Sheet: Reverse Repos ($ Mil)": "WLRRAL",
               ### Major share of deposits 
               "Balance Sheet: Deposits from Dep. Institutions ($ Mil)":"WLODLL",
               "Balance Sheet: U.S. Treasury General Account ($ Mil)": "WDTGAL",
               "Balance Sheet: Other Deposits ($ Mil)": "WOTHLB",
               "Balance Sheet: All Deposits ($ Mil)": "WLDLCL",
               # Capital
               "Balance Sheet: Total Capital": "WCTCL",
               # Interest Rates
               "Unemployment Rate": "UNRATE",
               "Nominal GDP ($ Bil)":"GDP",
               "Real GDP ($ Bil)":"GDPC1",
               "GDP Deflator":"GDPDEF",
               "CPI":"CPIAUCSL",
               "Core PCE":"PCEPILFE",
               "Private Investment":"GPDI",
               "Base: Total ($ Mil)": "BOGMBASE",
               "Base: Currency in Circulation ($ Bil)": "WCURCIR",
               "1 Month Treasury Rate (%)": "DGS1MO",
               "3 Month Treasury Rate (%)": "DGS3MO",               
               "1 Year Treasury Rate (%)": "DGS1",
               "2 Year Treasury Rate (%)": "DGS2",
               "10 Year Treasury Rate (%)": "DGS10",
               "30 Year Treasury Rate (%)": "DGS30",               
               "Effective Federal Funds Rate (%)": "DFF",
               "Federal Funds Target Rate (Pre-crisis)":"DFEDTAR",
               "Federal Funds Upper Target":"DFEDTARU",
               "Federal Funds Lower Target":"DFEDTARL",
               "Interest on Reserves (%)": "IOER",
               "VIX": "VIXCLS",
                "5 Year Forward Rate": "T5YIFR"
               }
inflation_target = .02
unemployment_target = .04
# Select start and end dates
start = datetime.datetime(2001, 12, 1)
end = datetime.datetime.today()
annual_div = {"Q":4,
             "W":52,
             "M":12}
# freq refers to data frequency. Choose "D", "W", "M", "Q", "A"
# a number may also be place in front of a letter. "2D" indicates
#       alternating days
if "data_gathered" not in locals():
    freq = "M"
    year = annual_div[freq]
    data = gather_data(data_codes, start, 
          end = end, freq = freq)
    data.fillna(0, inplace=True)
    for key in data.keys():
        data["Log " + key]= np.log(data[key])
    # Create new variables
    data_gathered = True

ticker = "^GSPC"
data["Base: Currency in Circulation ($ Mil)"] = data["Base: Currency in Circulation ($ Bil)"].mul(1000)
data["Base: Currency not in Circulation ($ Mil)"] = data["Base: Total ($ Mil)"].sub(data["Base: Currency in Circulation ($ Mil)"])
data["Currency in Circulation Growth Rate (%)"] = data["Base: Currency in Circulation ($ Mil)"].pct_change(year) * 100
data["Currency in Circulation Growth Rate Diff (%)"] =  data["Currency in Circulation Growth Rate (%)"].diff(year)
data["% Currency not in Circulation"] = data["Base: Currency not in Circulation ($ Mil)"].div(data["Base: Total ($ Mil)"]) * 100
data["% Currency in Circulation"] = data["Base: Currency in Circulation ($ Mil)"].div(data["Base: Total ($ Mil)"]) * 100
data["Base: Total Growth Rate (%)"] = data["Base: Total ($ Mil)"]
data["Change % Currency not in Circulation"] = data["% Currency not in Circulation"].diff(year)    
data["Currency not in Circulation Growth Rate (%)"] = data["Base: Currency not in Circulation ($ Mil)"].pct_change(year) * 100    
data["Inflation (CPI)"] =  web.DataReader("CPIAUCSL", "fred", start, end).resample(freq).mean().pct_change(year).mul(100).dropna()
data["Inflation (PCE)"] = web.DataReader("PCEPILFE", "fred", start, end).resample(freq).mean().pct_change(year).mul(100).dropna()

data["Effective Federal Funds Rate Diff (%)"] = data["Effective Federal Funds Rate (%)"].diff(year)
data["1 Year Treasury Rate (%; diff)"] = data["1 Year Treasury Rate (%)"].diff(year)
data["2 Year Treasury Rate (%; diff)"] = data["2 Year Treasury Rate (%)"].diff(year)
data["10 Year Treasury Rate (%; diff)"] = data["10 Year Treasury Rate (%)"].diff(year)
data["30 Year Treasury Rate (%; diff)"] = data["30 Year Treasury Rate (%)"].diff(year)
data["Unemployment Rate Diff"] = data["Unemployment Rate"].diff(year)
data["Nominal GDP ($ Mil)"] = data["Nominal GDP ($ Bil)"].mul(1000)
data["Nominal GDP Growth Rate (%)"] = data["Nominal GDP ($ Bil)"].pct_change(year) * 100
data["Real GDP ($ Mil)"] = data["Real GDP ($ Bil)"].mul(1000)
data["Real GDP Growth Rate (%)"] = data["Real GDP ($ Bil)"].pct_change(year) * 100
data["Inflation (GDPDEF)"] = data["GDP Deflator"].pct_change(year) * 100
data["Real Currency in Circulation Growth Rate (%)"] = data["Currency in Circulation Growth Rate (%)"].sub(data["Inflation (GDPDEF)"])
data["Currency in Circulation Velocity"] = data["Nominal GDP ($ Mil)"].div(data["Base: Currency in Circulation ($ Mil)"])
data["Currency in Circulation % Change Velocity"] = data["Currency in Circulation Velocity"].pct_change(year)

data["Inflation Loss"]= data["Inflation (PCE)"].sub(inflation_target)
data["Unemployment Loss"]= data["Unemployment Rate"].sub(unemployment_target)
data["Inflation Loss Sq"]= data["Inflation (PCE)"].sub(inflation_target).pow(2)
data["Inflation Loss Sq"][data["Inflation Loss"] < 0] = data["Inflation Loss Sq"].mul(-1)

data["Unemployment Loss Sq"]= data["Unemployment Rate"].sub(unemployment_target).pow(2)
data["Unemployment Loss Sq"][data["Unemployment Loss"] < 0] = data["Unemployment Loss Sq"].mul(-1)



data["Inflation Loss Diff"]= data["Inflation Loss"].diff(year)
data["Unemployment Loss Diff"]= data["Unemployment Loss"].diff(year)
data["Inflation Loss Sq Diff"]= data["Inflation Loss Sq"].diff(year)
data["Unemployment Loss Sq Diff"]= data["Unemployment Loss Sq"].diff(year)



data["Linear Loss"] = data["Inflation Loss"].sub(data["Unemployment Loss"])
data["Loss Function"] = data["Inflation Loss Sq"].sub(data["Unemployment Loss Sq"])
data["Linear Loss Diff"] = data["Linear Loss"].diff(year)
data["Loss Function Diff"] = data["Loss Function"].diff(year)

data["Real 1 Year Treasury Rate"] = data["1 Year Treasury Rate (%)"].sub(data["Inflation (CPI)"])
data["Real 3 Month Treasury Rate"] = data["3 Month Treasury Rate (%)"].sub(data["Inflation (CPI)"])
data["Real 1 Month Treasury Rate"] = data["1 Month Treasury Rate (%)"].sub(data["Inflation (CPI)"])
data["Real Effective Federal Funds Rate"] = data['Effective Federal Funds Rate (%)'].sub(data["Inflation (CPI)"])

data["30 Year Minus 1 Year (%)"] = data["30 Year Treasury Rate (%)"].sub(data["1 Year Treasury Rate (%)"])
data["30 Year Minus 3 Month (%)"] = data["30 Year Treasury Rate (%)"].sub(data["3 Month Treasury Rate (%)"])
data["30 Year Minus 1 Month (%)"] = data["30 Year Treasury Rate (%)"].sub(data["1 Month Treasury Rate (%)"])
data["30 Year Minus Effective Federal Funds Rate"] = data["30 Year Treasury Rate (%)"].sub(data['Effective Federal Funds Rate (%)'])
data["10 Year Minus 2 Year (%)"] = data["10 Year Treasury Rate (%)"].sub(data["2 Year Treasury Rate (%)"])
data["10 Year Minus 1 Year (%)"] = data["10 Year Treasury Rate (%)"].sub(data["1 Year Treasury Rate (%)"])
data["10 Year Minus 3 Month (%)"] = data["10 Year Treasury Rate (%)"].sub(data["3 Month Treasury Rate (%)"])
data["10 Year Minus 1 Month (%)"] = data["10 Year Treasury Rate (%)"].sub(data["1 Month Treasury Rate (%)"])
data["10 Year Minus Effective Federal Funds Rate"] = data["10 Year Treasury Rate (%)"].sub(data['Effective Federal Funds Rate (%)'])

keys = list(data.keys())
keys = ["Date"] + keys
data["Date"] = data.index.astype(str)
# Out:
# C:\Users\JLCat\anaconda3\lib\site-packages\pandas\core\arraylike.py:358: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
# import pandas_datareader.data as web
# start = datetime.datetime(2001, 12, 1)
# end = datetime.datetime.today()
# x =  web.DataReader("CPIAUCSL", "fred", start, end).resample(freq).mean().pct_change(year).mul(100).dropna()
# x

# %%
import yfinance as yfin
yfin.pdr_override()
data["S&P"]= web.get_data_yahoo(ticker, start = start, end = end).resample(freq).mean()["Close"].iloc[:-2]
data["S&P Growth Rate (%)"] = data["S&P"].pct_change(year)
data["S&P Growth Rate Change Diff (%)"] = data["S&P Growth Rate (%)"].diff(year)
data["Real S&P Growth Rate (%)"] = data["S&P Growth Rate (%)"].sub(data["Inflation (CPI)"])
data["VIX Diff"] = data["VIX"].diff(year)
data
# Out:
# [*********************100%***********************]  1 of 1 completed
#             Balance Sheet: Total Assets ($ Mil)  \
# DATE
# 2002-12-31                            725800.50
# 2003-01-31                            724718.40
# 2003-02-28                            721326.00
# 2003-03-31                            723651.25
# 2003-04-30                            736926.40
# ...                                         ...
# 2021-05-31                           7866893.25
# 2021-06-30                           8026555.20
# 2021-07-31                           8190356.75
# 2021-08-31                           8291893.25
# 2021-09-30                           8353243.50
#
#             Balance Sheet Securities, Prem-Disc, Repos, and Loans ($ Mil)  \
# DATE
# 2002-12-31                                          672844.50
# 2003-01-31                                          671196.20
# 2003-02-28                                          668666.25
# 2003-03-31                                          672446.00
# 2003-04-30                                          685518.60
# ...                                                       ...
# 2021-05-31                                         7709974.25
# 2021-06-30                                         7874851.20
# 2021-07-31                                         8042917.00
# 2021-08-31                                         8153497.75
# 2021-09-30                                         8221982.00
#
#             Balance Sheet: Securities Held Outright ($ Mil)  \
# DATE
# 2002-12-31                                        629409.50
# 2003-01-31                                        629416.00
# 2003-02-28                                        631911.75
# 2003-03-31                                        639168.25
# 2003-04-30                                        645508.60
# ...                                                     ...
# 2021-05-31                                       7291913.75
# 2021-06-30                                       7450341.40
# 2021-07-31                                       7617340.75
# 2021-08-31                                       7733453.75
# 2021-09-30                                       7809620.50
#
#             Balance Sheet: U.S. Treasuries Held Outright ($ Mil)  \
# DATE
# 2002-12-31                                          629399.50
# 2003-01-31                                          629406.00
# 2003-02-28                                          631901.75
# 2003-03-31                                          639158.25
# 2003-04-30                                          645498.60
# ...                                                       ...
# 2021-05-31                                         5063447.75
# 2021-06-30                                         5149903.00
# 2021-07-31                                         5232755.50
# 2021-08-31                                         5312788.25
# 2021-09-30                                         5369205.50
#
#             Balance Sheet: Federal Agency Debt Securities ($ Mil)  \
# DATE
# 2002-12-31                                               10.0
# 2003-01-31                                               10.0
# 2003-02-28                                               10.0
# 2003-03-31                                               10.0
# 2003-04-30                                               10.0
# ...                                                       ...
# 2021-05-31                                             2347.0
# 2021-06-30                                             2347.0
# 2021-07-31                                             2347.0
# 2021-08-31                                             2347.0
# 2021-09-30                                             2347.0
#
#             Balance Sheet: Mortgage-Backed Securities ($ Mil)  \
# DATE
# 2002-12-31                                               0.00
# 2003-01-31                                               0.00
# 2003-02-28                                               0.00
# 2003-03-31                                               0.00
# 2003-04-30                                               0.00
# ...                                                       ...
# 2021-05-31                                         2226119.00
# 2021-06-30                                         2298091.20
# 2021-07-31                                         2382238.75
# 2021-08-31                                         2418318.75
# 2021-09-30                                         2438068.00
#
#             Balance Sheet: Repos ($ Mil)  \
# DATE
# 2002-12-31                      33625.00
# 2003-01-31                      32100.00
# 2003-02-28                      27185.50
# 2003-03-31                      23625.00
# 2003-04-30                      30350.20
# ...                                  ...
# 2021-05-31                         11.75
# 2021-06-30                          0.00
# 2021-07-31                          0.00
# 2021-08-31                          0.00
# 2021-09-30                          0.00
#
#             Balance Sheet: Central Bank Liquidity Swaps ($ Mil)  \
# DATE
# 2002-12-31                                                0.0
# 2003-01-31                                                0.0
# 2003-02-28                                                0.0
# 2003-03-31                                                0.0
# 2003-04-30                                                0.0
# ...                                                       ...
# 2021-05-31                                              642.5
# 2021-06-30                                              516.0
# 2021-07-31                                              487.0
# 2021-08-31                                              446.0
# 2021-09-30                                              332.5
#
#             Balance Sheet: Direct Lending ($ Mil)  \
# DATE
# 2002-12-31                                  52.00
# 2003-01-31                                  19.40
# 2003-02-28                                  10.50
# 2003-03-31                                  11.00
# 2003-04-30                                  31.80
# ...                                           ...
# 2021-05-31                               81423.00
# 2021-06-30                               87694.60
# 2021-07-31                               87349.25
# 2021-08-31                               81331.75
# 2021-09-30                               73888.00
#
#             Balance Sheet: Unamortized Security Premiums ($ Mil)  ...  \
# DATE                                                              ...
# 2002-12-31                                           10811.00     ...
# 2003-01-31                                           10688.00     ...
# 2003-02-28                                           10571.25     ...
# 2003-03-31                                           10619.25     ...
# 2003-04-30                                           10574.40     ...
# ...                                                       ...     ...
# 2021-05-31                                          349622.50     ...
# 2021-06-30                                          350797.60     ...
# 2021-07-31                                          352744.75     ...
# 2021-08-31                                          353699.00     ...
# 2021-09-30                                          354023.00     ...
#
#             10 Year Minus 1 Year (%)  10 Year Minus 3 Month (%)  \
# DATE
# 2002-12-31                  2.582381                   2.821429
# 2003-01-31                  2.684286                   2.859524
# 2003-02-28                  2.606316                   2.717368
# 2003-03-31                  2.567143                   2.656190
# 2003-04-30                  2.691429                   2.806190
# ...                              ...                        ...
# 2021-05-31                  1.570500                   1.603000
# 2021-06-30                  1.452273                   1.483182
# 2021-07-31                  1.242857                   1.266190
# 2021-08-31                  1.209545                   1.228636
# 2021-09-30                  1.251667                   1.278333
#
#             10 Year Minus 1 Month (%)  \
# DATE
# 2002-12-31                   2.834762
# 2003-01-31                   2.878095
# 2003-02-28                   2.707368
# 2003-03-31                   2.630952
# 2003-04-30                   2.800476
# ...                               ...
# 2021-05-31                   1.613500
# 2021-06-30                   1.491818
# 2021-07-31                   1.269048
# 2021-08-31                   1.241818
# 2021-09-30                   1.278333
#
#             10 Year Minus Effective Federal Funds Rate        Date  \
# DATE
# 2002-12-31                                    2.793994  2002-12-31
# 2003-01-31                                    2.813410  2003-01-31
# 2003-02-28                                    2.640489  2003-02-28
# 2003-03-31                                    2.554240  2003-03-31
# 2003-04-30                                    2.700571  2003-04-30
# ...                                                ...         ...
# 2021-05-31                                    1.562935  2021-05-31
# 2021-06-30                                    1.441091  2021-06-30
# 2021-07-31                                    1.220507  2021-07-31
# 2021-08-31                                    1.190924  2021-08-31
# 2021-09-30                                    1.246667  2021-09-30
#
#                     S&P  S&P Growth Rate (%)  S&P Growth Rate Change Diff (%)  \
# DATE
# 2002-12-31   899.178574                  NaN                              NaN
# 2003-01-31   895.836190                  NaN                              NaN
# 2003-02-28   837.618951                  NaN                              NaN
# 2003-03-31   846.621425                  NaN                              NaN
# 2003-04-30   890.025713                  NaN                              NaN
# ...                 ...                  ...                              ...
# 2021-05-31  4167.849536             0.427537                         0.404802
# 2021-06-30  4238.489546             0.365202                         0.290987
# 2021-07-31  4363.712798             0.360421                         0.289828
# 2021-08-31          NaN             0.286582                         0.115998
# 2021-09-30          NaN             0.296595                         0.168044
#
#             Real S&P Growth Rate (%)   VIX Diff
# DATE
# 2002-12-31                       NaN        NaN
# 2003-01-31                       NaN        NaN
# 2003-02-28                       NaN        NaN
# 2003-03-31                       NaN        NaN
# 2003-04-30                       NaN        NaN
# ...                              ...        ...
# 2021-05-31                 -4.498970 -11.136500
# 2021-06-30                 -4.959306 -14.162727
# 2021-07-31                 -4.922173  -9.237121
# 2021-08-31                       NaN  -5.416797
# 2021-09-30                       NaN -10.342619
#
# [226 rows x 136 columns]

# %%
#fedProject
# . . . 
data["Balance Sheet: Direct Lending and Central Bank Liquidity Swaps"] =\
    data["Balance Sheet: Central Bank Liquidity Swaps ($ Mil)"].add(
    data["Balance Sheet: Direct Lending ($ Mil)"])
data["Balance Sheet: Other Securities"] = data["Balance Sheet: Securities Held Outright ($ Mil)"].sub(
    data["Balance Sheet: U.S. Treasuries Held Outright ($ Mil)"]).sub(
    data["Balance Sheet: Mortgage-Backed Securities ($ Mil)"])
data["Balance Sheet: Other Assets"] = data["Balance Sheet: Total Assets ($ Mil)"].sub(
    data["Balance Sheet: Securities Held Outright ($ Mil)"]).sub(
    data["Balance Sheet: Direct Lending and Central Bank Liquidity Swaps"]).sub(
    data["Balance Sheet: Repos ($ Mil)"]).sub(
    data["Balance Sheet: Unamortized Security Premiums ($ Mil)"])
data["Balance Sheet: Other Deposits ($ Mil)"] = data["Balance Sheet: All Deposits ($ Mil)"].sub(
    data["Balance Sheet: U.S. Treasury General Account ($ Mil)"]).sub(
    data["Balance Sheet: Deposits from Dep. Institutions ($ Mil)"])
data["Balance Sheet: Other Liabilities"]= data["Balance Sheet: Total Liabilities ($ Mil)"].sub(
    data["Balance Sheet: Federal Reserve Notes Outstanding ($ Mil)"]).sub(
    data["Balance Sheet: U.S. Treasury General Account ($ Mil)"]).sub(
    data["Balance Sheet: Deposits from Dep. Institutions ($ Mil)"]).sub(
    data["Balance Sheet: Other Deposits ($ Mil)"]).sub(
    data["Balance Sheet: Reverse Repos ($ Mil)"])

# %%
plt.rcParams.update({"font.size":32})
interest_vars = ["Effective Federal Funds Rate (%)",
                   "Interest on Reserves (%)",
                   "1 Month Treasury Rate (%)"]
fig, ax = plt.subplots(figsize = (30,20))
data[interest_vars].plot.line(legend=True, linewidth = 3, ax = ax)
y_vals = ax.get_yticks()
ax.set_yticklabels([str(round(y,2))+ "%" for y in y_vals])  
ax.set_title("Short Term Interest Rates", fontsize = 48)
data[["Date"] + interest_vars].to_json("shortTermRates.json", orient="records")
# Out:
# <ipython-input-5-ab5c1d4011df>:8: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels([str(round(y,2))+ "%" for y in y_vals])

# %%
data = data.rename(columns = {
    key: key.replace("Balance Sheet: ", "").replace(" ($ Mil)", "").replace("Base: ","") for key in data.keys()})
keys = list(data.keys())
interest_rates = ["Effective Federal Funds Rate (%)",
                   "Interest on Reserves (%)",
                   "1 Month Treasury Rate (%)"]
plot_data = data.copy()
for key, val in data.items():
    if key not in interest_rates:
        try:
            plot_data[key] = val.div(10**6)
        except:
            continue

# %%
account_vars = ["U.S. Treasuries Held Outright",
               "Mortgage-Backed Securities",
               "Other Securities",
               "Direct Lending and Central Bank Liquidity Swaps",
               "Repos",
               "Unamortized Security Premiums",
               "Other Assets"]
figsize= (36,18)
fig, ax = plt.subplots(figsize = figsize)
plot_data[account_vars].plot.area(stacked = True, linewidth = 3,
                            ax = ax)
# change y vals from mil to tril
total_var = "Total Assets"
plot_data[total_var].plot.line(linewidth = 1, 
                             ax = ax, c = "k",
                             label = total_var, ls = "--")
plt.xticks(rotation = 90)
ax.legend(loc=2, ncol = 2)
ax.set_ylabel("$ Trillion", fontsize = 40)
ax.set_title("Federal Reserve Balance Sheet: Assets", fontsize = 50)
plot_data[[total_var] + account_vars].to_csv("FederalReserveAssets.csv")
plot_data[["Date"] + account_vars].to_json("fedAssets.json", orient = "records")

# %%
account_vars = ["Federal Reserve Notes Outstanding",
                "U.S. Treasury General Account",
                "Deposits from Dep. Institutions",
                "Other Deposits",
                "Reverse Repos",
                "Other Liabilities"]
total_var = "Total Liabilities"

plot_stacked_lines(
    plot_data,
    account_vars, linewidth = 1,
    total_var = "Total Liabilities")

# %%
figsize= (36,18)
fig, ax = plt.subplots(figsize = figsize)
plot_data[account_vars].plot.area(stacked = True, linewidth = 3,
                            ax = ax)
# change y vals from mil to tril
total_var = "Total Liabilities"
plot_data[total_var].plot.line(linewidth = 2, 
                             ax = ax, c = "k",
                             label = total_var, ls = "--")
plt.xticks(rotation = 90)
ax.legend(loc=2, ncol = 2)
ax.set_ylabel("$ Trillion", fontsize = 40)
ax.set_title("Federal Reserve Balance Sheet: Liabilities", fontsize = 50)
plot_data[[total_var] + account_vars].to_csv("FederalReserveLiabilities.csv")

# %%
plt.rcParams.update({"font.size":32})
df = plot_data.copy()
for key in account_vars:
    df[key] = df[key].div(df["Total Liabilities"])
figsize= (36,18)
fig, ax = plt.subplots(figsize = figsize)
df[account_vars].plot.area(stacked = True, linewidth = 3,
                            ax = ax)
plt.xticks(rotation= 90, fontsize = 45)
ax.set_yticklabels([str(int(val * 100)) + "% " for val in ax.get_yticks()], fontsize = 45)

#plt.yticks([int(tick * 100) for tick in ax.get_yticks() if tick <1.01])
plt.title("Liabilities as a Proportion of the\nFederal Reserve's Balance Sheet", fontsize =45)
plt.show()
# Out:
# <ipython-input-10-bd89c59b9c46>:10: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels([str(int(val * 100)) + "% " for val in ax.get_yticks()], fontsize = 45)

# %%
plot_data["Net Effect on Overnight Lending Market"] =\
    plot_data["Repos"].sub(plot_data["Reverse Repos"])
overnight_vars = ["Repos",
                  "Reverse Repos",
                  "Net Effect on Overnight Lending Market"]
fig, ax = plt.subplots(figsize = (30,20))
plot_data[overnight_vars].plot.line(legend=True, linewidth = 3, ax = ax)
ax.set_ylabel("$ Trillion", fontsize = 40)
ax.set_title("Federal Reserve Activity\nin Overnight Lending Market", fontsize = 48)
plot_data[["Date"] + overnight_vars].to_json("overnightLending.json", orient="records")

# %%
data["Total Liabilities Growth Rate (%)"] = data["Total Liabilities"].pct_change(year)
data["Total Assets Growth Rate (%)"] = data["Total Assets"].pct_change(year)
data["Total Assets Growth Rate Diff (%)"] = data["Total Assets"].diff(year)

data["Total Liabilities / Currency in Circulation"] = data["Total Liabilities"].div(data["Currency in Circulation ($ Bil)"].mul(1000))
data["Total Assets / Currency in Circulation"] = data["Total Assets"].div(data["Currency in Circulation ($ Bil)"].mul(1000))
data["Currency in Circulation / Total Assets"] = data["Currency in Circulation ($ Bil)"].mul(1000).div(data["Total Assets"])
data["Currency in Circulation / Total Assets Diff"] = data["Currency in Circulation / Total Assets"].diff(year)
data["Currency in Circulation / Total Liabilities"] = data["Currency in Circulation ($ Bil)"].mul(1000).div(data["Total Liabilities"])
data["Currency in Circulation / Total Liabilities Diff"] = data["Currency in Circulation / Total Liabilities"].diff(year)

data["Log Total Liabilities"] = np.log(data["Total Liabilities"])
data["Log Total Assets"] = np.log(data["Total Assets"])
#data["Currency in Circulation / Total Liabilities %"] = data["Currency in Circulation / Total Liabilities"].pct_change()

# %%
# pd.set_option('display.max_rows', None)
# pd.set_option('display.max_columns', None)
data
# Out:
#             Total Assets  \
# DATE
# 2002-12-31     725800.50
# 2003-01-31     724718.40
# 2003-02-28     721326.00
# 2003-03-31     723651.25
# 2003-04-30     736926.40
# ...                  ...
# 2021-05-31    7866893.25
# 2021-06-30    8026555.20
# 2021-07-31    8190356.75
# 2021-08-31    8291893.25
# 2021-09-30    8353243.50
#
#             Balance Sheet Securities, Prem-Disc, Repos, and Loans  \
# DATE
# 2002-12-31                                          672844.50
# 2003-01-31                                          671196.20
# 2003-02-28                                          668666.25
# 2003-03-31                                          672446.00
# 2003-04-30                                          685518.60
# ...                                                       ...
# 2021-05-31                                         7709974.25
# 2021-06-30                                         7874851.20
# 2021-07-31                                         8042917.00
# 2021-08-31                                         8153497.75
# 2021-09-30                                         8221982.00
#
#             Securities Held Outright  U.S. Treasuries Held Outright  \
# DATE
# 2002-12-31                 629409.50                      629399.50
# 2003-01-31                 629416.00                      629406.00
# 2003-02-28                 631911.75                      631901.75
# 2003-03-31                 639168.25                      639158.25
# 2003-04-30                 645508.60                      645498.60
# ...                              ...                            ...
# 2021-05-31                7291913.75                     5063447.75
# 2021-06-30                7450341.40                     5149903.00
# 2021-07-31                7617340.75                     5232755.50
# 2021-08-31                7733453.75                     5312788.25
# 2021-09-30                7809620.50                     5369205.50
#
#             Federal Agency Debt Securities  Mortgage-Backed Securities  \
# DATE
# 2002-12-31                            10.0                        0.00
# 2003-01-31                            10.0                        0.00
# 2003-02-28                            10.0                        0.00
# 2003-03-31                            10.0                        0.00
# 2003-04-30                            10.0                        0.00
# ...                                    ...                         ...
# 2021-05-31                          2347.0                  2226119.00
# 2021-06-30                          2347.0                  2298091.20
# 2021-07-31                          2347.0                  2382238.75
# 2021-08-31                          2347.0                  2418318.75
# 2021-09-30                          2347.0                  2438068.00
#
#                Repos  Central Bank Liquidity Swaps  Direct Lending  \
# DATE
# 2002-12-31  33625.00                           0.0           52.00
# 2003-01-31  32100.00                           0.0           19.40
# 2003-02-28  27185.50                           0.0           10.50
# 2003-03-31  23625.00                           0.0           11.00
# 2003-04-30  30350.20                           0.0           31.80
# ...              ...                           ...             ...
# 2021-05-31     11.75                         642.5        81423.00
# 2021-06-30      0.00                         516.0        87694.60
# 2021-07-31      0.00                         487.0        87349.25
# 2021-08-31      0.00                         446.0        81331.75
# 2021-09-30      0.00                         332.5        73888.00
#
#             Unamortized Security Premiums  ...  Other Liabilities  \
# DATE                                       ...
# 2002-12-31                       10811.00  ...           10742.50
# 2003-01-31                       10688.00  ...           10218.00
# 2003-02-28                       10571.25  ...            9699.50
# 2003-03-31                       10619.25  ...            9072.00
# 2003-04-30                       10574.40  ...            9784.00
# ...                                   ...  ...                ...
# 2021-05-31                      349622.50  ...           61712.25
# 2021-06-30                      350797.60  ...           59004.00
# 2021-07-31                      352744.75  ...           52049.00
# 2021-08-31                      353699.00  ...           49596.00
# 2021-09-30                      354023.00  ...           50032.00
#
#             Total Liabilities Growth Rate (%)  Total Assets Growth Rate (%)  \
# DATE
# 2002-12-31                                NaN                           NaN
# 2003-01-31                                NaN                           NaN
# 2003-02-28                                NaN                           NaN
# 2003-03-31                                NaN                           NaN
# 2003-04-30                                NaN                           NaN
# ...                                       ...                           ...
# 2021-05-31                           0.132997                      0.132325
# 2021-06-30                           0.126694                      0.126094
# 2021-07-31                           0.177575                      0.176703
# 2021-08-31                           0.189586                      0.188650
# 2021-09-30                           0.186061                      0.185131
#
#             Total Assets Growth Rate Diff (%)  \
# DATE
# 2002-12-31                                NaN
# 2003-01-31                                NaN
# 2003-02-28                                NaN
# 2003-03-31                                NaN
# 2003-04-30                                NaN
# ...                                       ...
# 2021-05-31                          919338.00
# 2021-06-30                          898768.95
# 2021-07-31                         1229927.35
# 2021-08-31                         1316001.00
# 2021-09-30                         1304869.30
#
#             Total Liabilities / Currency in Circulation  \
# DATE
# 2002-12-31                                     1.046535
# 2003-01-31                                     1.041374
# 2003-02-28                                     1.035709
# 2003-03-31                                     1.033573
# 2003-04-30                                     1.047029
# ...                                                 ...
# 2021-05-31                                     3.610492
# 2021-06-30                                     3.665537
# 2021-07-31                                     3.728183
# 2021-08-31                                     3.771969
# 2021-09-30                                     3.791084
#
#             Total Assets / Currency in Circulation  \
# DATE
# 2002-12-31                                1.072920
# 2003-01-31                                1.066686
# 2003-02-28                                1.061035
# 2003-03-31                                1.058878
# 2003-04-30                                1.072587
# ...                                            ...
# 2021-05-31                                3.628665
# 2021-06-30                                3.683695
# 2021-07-31                                3.746297
# 2021-08-31                                3.790131
# 2021-09-30                                3.809252
#
#             Currency in Circulation / Total Assets  \
# DATE
# 2002-12-31                                0.932036
# 2003-01-31                                0.937483
# 2003-02-28                                0.942476
# 2003-03-31                                0.944396
# 2003-04-30                                0.932326
# ...                                            ...
# 2021-05-31                                0.275583
# 2021-06-30                                0.271467
# 2021-07-31                                0.266930
# 2021-08-31                                0.263843
# 2021-09-30                                0.262519
#
#             Currency in Circulation / Total Assets Diff  \
# DATE
# 2002-12-31                                          NaN
# 2003-01-31                                          NaN
# 2003-02-28                                          NaN
# 2003-03-31                                          NaN
# 2003-04-30                                          NaN
# ...                                                 ...
# 2021-05-31                                    -0.002173
# 2021-06-30                                    -0.002864
# 2021-07-31                                    -0.017286
# 2021-08-31                                    -0.023507
# 2021-09-30                                    -0.024958
#
#             Currency in Circulation / Total Liabilities  \
# DATE
# 2002-12-31                                     0.955534
# 2003-01-31                                     0.960270
# 2003-02-28                                     0.965522
# 2003-03-31                                     0.967518
# 2003-04-30                                     0.955083
# ...                                                 ...
# 2021-05-31                                     0.276971
# 2021-06-30                                     0.272811
# 2021-07-31                                     0.268227
# 2021-08-31                                     0.265114
# 2021-09-30                                     0.263777
#
#             Currency in Circulation / Total Liabilities Diff
# DATE
# 2002-12-31                                               NaN
# 2003-01-31                                               NaN
# 2003-02-28                                               NaN
# 2003-03-31                                               NaN
# 2003-04-30                                               NaN
# ...                                                      ...
# 2021-05-31                                         -0.002350
# 2021-06-30                                         -0.003025
# 2021-07-31                                         -0.017582
# 2021-08-31                                         -0.023848
# 2021-09-30                                         -0.025305
#
# [226 rows x 149 columns]

# %%
import pingouin
plot_vars = ["Inflation (PCE)",
             "Unemployment Rate",
             "Inflation Loss",
             "Unemployment Loss",
             "Linear Loss",
             "Loss Function",
             "Effective Federal Funds Rate (%)",
             "Currency in Circulation Growth Rate (%)",
             "Currency in Circulation / Total Assets",
             "Total Assets Growth Rate (%)"]
#data[plot_vars].describe().T.to_excel("C:\\Users\\JLCat\\OneDrive\\Documents\\For NDSU\\Projects\\Sound Money Project\\Frederal Reserve QE Framework\\DescriptionStatistics.xls")
#data[plot_vars].describe().corr()
#data[plot_vars].describe().pcorr()

# %%
plot_vars = [#Currency in Circulation Growth Rate (%)",
             #"Currency not in Circulation Growth Rate (%)",
             #"5 Year Forward Rate",
             #"Inflation (CPI)",
             #"Unemployment Rate Diff",
             #"Loss Function Diff",
            #"Unemployment Loss Diff",
            #"Inflation Loss Diff",
            #"Linear Loss Diff",
            #"Unemployment Loss Sq Diff",
            #"Inflation Loss Sq Diff",
            "Linear Loss Diff",
    #"Currency in Circulation % Change Velocity",
             #"Nominal GDP Growth Rate (%)",
             #"Real GDP Growth Rate (%)",
             "Effective Federal Funds Rate Diff (%)",
             #"30 Year Treasury Rate (%)",
             #"1 Month Treasury Rate (%)",
             #"S&P Growth Rate (%)",
             "Currency in Circulation / Total Assets Diff",
             #Total Assets Growth Rate (%)",
             "VIX Diff"
]
dag_df = data[plot_vars].dropna().rename(columns={key: key.replace(" ", "\n") for key in plot_vars}).loc["2008-10-01":"2020-08-01"]
dag_df.pcorr().round(2)
# Out:
#                                                    Linear\nLoss\nDiff  \
# Linear\nLoss\nDiff                                               1.00
# Effective\nFederal\nFunds\nRate\nDiff\n(%)                       0.44
# Currency\nin\nCirculation\n/\nTotal\nAssets\nDiff                0.09
# VIX\nDiff                                                        0.14
#
#                                                    Effective\nFederal\nFunds\nRate\nDiff\n(%)  \
# Linear\nLoss\nDiff                                                                       0.44
# Effective\nFederal\nFunds\nRate\nDiff\n(%)                                               1.00
# Currency\nin\nCirculation\n/\nTotal\nAssets\nDiff                                        0.71
# VIX\nDiff                                                                               -0.27
#
#                                                    Currency\nin\nCirculation\n/\nTotal\nAssets\nDiff  \
# Linear\nLoss\nDiff                                                                              0.09
# Effective\nFederal\nFunds\nRate\nDiff\n(%)                                                      0.71
# Currency\nin\nCirculation\n/\nTotal\nAssets\nDiff                                               1.00
# VIX\nDiff                                                                                      -0.06
#
#                                                    VIX\nDiff
# Linear\nLoss\nDiff                                      0.14
# Effective\nFederal\nFunds\nRate\nDiff\n(%)             -0.27
# Currency\nin\nCirculation\n/\nTotal\nAssets\nDiff      -0.06
# VIX\nDiff                                               1.00

# %%
pp.close()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-61-c1dc95bd5ca6> in <module>
# ----> 1 pp.close()
#
# ~\anaconda3\lib\site-packages\matplotlib\backends\backend_pdf.py in close(self)
#    2498         PDF file.
#    2499         """
# -> 2500         self._file.finalize()
#    2501         self._file.close()
#    2502         if (self.get_pagecount() == 0 and not self.keep_empty and
#
# AttributeError: 'NoneType' object has no attribute 'finalize'

# %%
from pgmpy.estimators import PC
from pgmpy.base import DAG
import matplotlib.pyplot as plt
from matplotlib.patches import ArrowStyle
import networkx as nx
from matplotlib.backends.backend_pdf import PdfPages
plt.rcParams.update({"font.size":20})

from matplotlib.patches import ArrowStyle

def graph_DAG(edges, df, pp, title = ""):
    graph = nx.DiGraph()
    edge_labels = {}
    for edge in edges:
        controls = [key for key in df.keys() if key not in edge]
        controls = list(set(controls))
        keep_controls = []
        for control in controls:
            control_edges = [ctrl_edge for ctrl_edge in edges if control == ctrl_edge[0] ]
            if (control, edge[1]) in control_edges:
                keep_controls.append(control)                
        pcorr = df[[edge[0], edge[1]]+keep_controls].pcorr()
        edge_labels[edge] = str(round(pcorr[edge[0]].loc[edge[1]],2))
    graph.add_edges_from(edges)
    color_map = ["grey" for g in graph]

    fig, ax = plt.subplots(figsize = (20,20))
    graph.nodes()
    plt.tight_layout()
    pos = nx.spring_layout(graph)#, k = 5/(len(sig_corr.keys())**.5))

    plt.title(title, fontsize = 30)
    nx.draw_networkx(graph, pos, node_color=color_map, node_size = 1200,
                     with_labels=True,  arrows=True,
                     #font_color = "white",
                     font_size = 26, alpha = 1,
                     width = 1, edge_color = "C1",
                     arrowstyle=ArrowStyle("Fancy, head_length=3, head_width=1.5, tail_width=.1"), ax = ax)
    nx.draw_networkx_edge_labels(graph,pos,
                                 edge_labels=edge_labels,
                                 font_color='green',
                                 font_size=20)
    pp.savefig(fig, bbox_inches = "tight")  
    plt.close()
diffs = ["", " Diff"]
# diffs = [" Diff"]
pp = PdfPages("MacroDAGs.pdf")
for diff in diffs:
    plot_vars_dct = {0: ["Loss Function" + diff,
                         "Effective Federal Funds Rate" +diff + " (%)",
                         "Currency in Circulation / Total Assets" + diff],
#                      1:["Currency in Circulation Growth Rate" +diff + " (%)",
#                         "Loss Function" + diff,
#                         "Effective Federal Funds Rate" +diff + " (%)",
#                         "Total Assets Growth Rate" +diff + " (%)"],
                     2:["Unemployment Loss Sq" + diff,
                        "Inflation Loss Sq" + diff,
                        "Effective Federal Funds Rate" +diff + " (%)",
                        "Currency in Circulation / Total Assets" + diff],
#                      3:["Currency in Circulation Growth Rate" +diff + " (%)",
#                         "Unemployment Loss Sq" + diff,
#                         "Inflation Loss Sq" + diff,
#                         "Effective Federal Funds Rate" +diff + " (%)",
#                         "Total Assets Growth Rate" +diff + " (%)"],
                        }

    sig = 0.05
    variant = "parallel"
    ci_test = "pearsonr"
    for key, plot_vars in plot_vars_dct.items():
        data1 = data[plot_vars].dropna().rename(columns={key: key.replace(" ", "\n") for key in plot_vars}).loc[:"2008-10-31"]
        start1 = str(list(data1.index)[0])[:-10]
        data2 = data[plot_vars].dropna().rename(columns={key: key.replace(" ", "\n") for key in plot_vars}).loc["2008-10-31":"2020-08-31"]
        
        dfs = {start1 + " to 2008-09-30":data1,
               "2008-10-31 to 2020-07-31": data2}

        for dates, dag_df in dfs.items():
            print(key, dates)
            dag_df = dag_df.dropna().rename(columns={key: key.replace("\nDiff", "") for key in dag_df.keys()})
            keys = dag_df.keys()
            c = PC(dag_df)
            max_cond_vars = len(keys) - 2
    #         print(dag_df.index)

            model = c.estimate(return_type = "dag",variant= variant, 
                               significance_level = sig, 
                               max_cond_vars = max_cond_vars, ci_test = ci_test)
            edges = model.edges()
            pcorr = dag_df.pcorr()
            weights = {}
    #         for edge in edges:
    #             print(edge, ":",pcorr[edge[0]].loc[edge[1]])
    #         skel, sep_sets = c.build_skeleton(variant = variant, ci_test = ci_test, significance_level = sig, 
    #                            max_cond_vars = max_cond_vars)


            graph_DAG(edges, dag_df, pp = pp, title = diff.replace(" ", "") + "\n" + dates)
pp.close()
# Out:
# Working for n conditional variables: 1: 100%|████████████████████████████████████████████| 1/1 [00:00<00:00, 77.12it/s]C:\Users\JLCat\anaconda3\lib\site-packages\pgmpy\estimators\PC.py:369: UserWarning: Reached maximum number of allowed conditional variables. Exiting
#   warn("Reached maximum number of allowed conditional variables. Exiting")
# Working for n conditional variables: 1: 100%|████████████████████████████████████████████| 1/1 [00:00<00:00, 24.45it/s]
# 0 2002-12-3 to 2008-09-30
# Working for n conditional variables: 1: 100%|███████████████████████████████████████████| 1/1 [00:00<00:00, 111.40it/s]C:\Users\JLCat\anaconda3\lib\site-packages\pgmpy\estimators\PC.py:369: UserWarning: Reached maximum number of allowed conditional variables. Exiting
#   warn("Reached maximum number of allowed conditional variables. Exiting")
# Working for n conditional variables: 1: 100%|████████████████████████████████████████████| 1/1 [00:00<00:00, 30.37it/s]
# 0 2008-10-31 to 2020-07-31
# Working for n conditional variables: 2: 100%|████████████████████████████████████████████| 2/2 [00:00<00:00, 20.46it/s]C:\Users\JLCat\anaconda3\lib\site-packages\pgmpy\estimators\PC.py:369: UserWarning: Reached maximum number of allowed conditional variables. Exiting
#   warn("Reached maximum number of allowed conditional variables. Exiting")
# Working for n conditional variables: 2: 100%|████████████████████████████████████████████| 2/2 [00:00<00:00, 15.43it/s]
# 2 2002-12-3 to 2008-09-30
# Working for n conditional variables: 2: 100%|████████████████████████████████████████████| 2/2 [00:00<00:00, 22.28it/s]C:\Users\JLCat\anaconda3\lib\site-packages\pgmpy\estimators\PC.py:369: UserWarning: Reached maximum number of allowed conditional variables. Exiting
#   warn("Reached maximum number of allowed conditional variables. Exiting")
# Working for n conditional variables: 2: 100%|████████████████████████████████████████████| 2/2 [00:00<00:00, 20.05it/s]
# 2 2008-10-31 to 2020-07-31
# Working for n conditional variables: 1: 100%|███████████████████████████████████████████| 1/1 [00:00<00:00, 100.25it/s]C:\Users\JLCat\anaconda3\lib\site-packages\pgmpy\estimators\PC.py:369: UserWarning: Reached maximum number of allowed conditional variables. Exiting
#   warn("Reached maximum number of allowed conditional variables. Exiting")
# Working for n conditional variables: 1: 100%|████████████████████████████████████████████| 1/1 [00:00<00:00, 24.45it/s]
# 0 2003-12-3 to 2008-09-30
# Working for n conditional variables: 1: 100%|███████████████████████████████████████████| 1/1 [00:00<00:00, 101.43it/s]C:\Users\JLCat\anaconda3\lib\site-packages\pgmpy\estimators\PC.py:369: UserWarning: Reached maximum number of allowed conditional variables. Exiting
#   warn("Reached maximum number of allowed conditional variables. Exiting")
# Working for n conditional variables: 1: 100%|████████████████████████████████████████████| 1/1 [00:00<00:00, 18.27it/s]

# %%
keys[1]
# Out:
# 'Inflation\nLoss\nSq'

# %%
from statsmodels.tsa.api import VAR
import statsmodels.api as sm

import copy
import pingouin
p_val = .01
def build_skeleton(df, undirected_graph):    
    def check_remaining_controls(control_vars, undirected_graph, x, y, controls_used) :
        c_used = copy.copy(controls_used)
        for c_var in control_vars:
            if y not in undirected_graph[x]:
                break
            c_used.append(c_var)
            test = df.partial_corr(x = x, y = y, covar=c_used,
                                  method = "pearson")
            if test["p-val"].values[0] > p_val: 

                undirected_graph[x].remove(y)
                #breakout of the for 
                break
            else:
                remaining_controls = copy.copy(control_vars)
                remaining_controls.remove(c_var)
                check_remaining_controls(remaining_controls, undirected_graph, x, y, c_used)
    d_sep = {}
    for x in df.keys():
        ys = undirected_graph[x]
        for y in df.keys():
            d_sep[(x,y)] = []

            if x != y:
            # first check for correlation with no controls
                test = df.partial_corr(x = x, y = y, covar = None,method = "pearson") 
                if test["p-val"].values[0] > p_val:
                    undirected_graph[x].remove(y)
            # if correlated check for deseparation controlling for other variables
                else:
                ############## make recursive function #############

                    control_vars = [z for z in df.keys() if z != y and z != x]
                    check_remaining_controls(control_vars, undirected_graph, x, y, [])
    return undirected_graph

# undirected_graph = build_skeleton(df, undirected_graph)                                   
# undirected_graph

diffs = ["", " Diff"]
for diff in diffs:
    plot_vars_dct = {0: ["Effective Federal Funds Rate" +diff + " (%)",
                         "Currency in Circulation / Total Assets" + diff,
                        "Linear Loss" + diff],
#                      1:["Currency in Circulation Growth Rate" +diff + " (%)",
#                         "Loss Function" + diff,
#                         "Effective Federal Funds Rate" +diff + " (%)",
#                         "Total Assets Growth Rate" +diff + " (%)"],
                     2:["Effective Federal Funds Rate" +diff + " (%)",
                        "Currency in Circulation / Total Assets" + diff,
                         "Unemployment Loss" + diff,
                        "Inflation Loss" + diff],

#                      3:["Currency in Circulation Growth Rate" +diff + " (%)",
#                         "Unemployment Loss Sq" + diff,
#                         "Inflation Loss Sq" + diff,
#                         "Effective Federal Funds Rate" +diff + " (%)",
#                         "Total Assets Growth Rate" +diff + " (%)"],
                    }
    for i in plot_vars_dct:
        residuals = {}
        var_data = data[plot_vars_dct[i]].dropna().loc["2009-07-31":"2020-03-31"]#.resample("Q").last()
        min_keys = list(var_data.keys())
        keys = list(var_data.keys())
        for key in var_data:
            for i in range(1, year + 1):
                new_key = key +" Lag " + str(i)
                var_data[new_key] = var_data[key].shift(i)
                keys.append(new_key)
        keys = list(var_data.keys())

#         for key in plot_vars_dct[i]:
#             Y = var_data[[key]]
#             keys.remove(key)
#             X = var_data[[keys]]
#             model = sm.OLS(Y,X)
#             predict = results.predict()
#             var_data[key + " predict"] = predict
#             residuals[key] = results.resid
        
        pcs_full = {key:{} for key in keys}
        pcs = {key:{} for key in keys}
        p_vals = {key:{} for key in keys}
        for key1 in keys:
            for key2 in keys:
                if key1 == key2:
                    pcs[key1][key2] = 1
                else:
                    pcs_full[key1][key2] = var_data.partial_corr(x = key1, y = key2, covar = None,method = "pearson") 
                    pcs[key1][key2] = pcs_full[key1][key2]["r"].values[0]
                    p_vals[key1][key2] = pcs_full[key1][key2]["p-val"].values[0]
        pcs_df = pd.DataFrame(pcs)
        p_vals_df = pd.DataFrame(p_vals)
        print(pcs_df.loc[min_keys, min_keys])
        print(p_vals_df.loc[min_keys, min_keys])

#         var_data = data[plot_vars_dct[i]].dropna().loc["2009-07-31":"2020-03-31"]#.resample("Q").last()
#         model = VAR(var_data)
#         results = model.fit(12)
#         results.summary()
#         irf = results.irf(24)
#         # irf.plot(orth=False)
#         for key in var_data.keys(): 
#             if "Funds" in key:
#                 irf.plot(impulse=key)
#                 plt.xlabel("Months")
#                 plt.show()
#                 plt.close()
#                 irf.plot_cum_effects(orth=False, impulse = key)
#                 plt.xlabel("Months")
#                 plt.show()
#                 plt.close()
# Out:
#                                         Effective Federal Funds Rate (%)  \
# Effective Federal Funds Rate (%)                                1.000000
# Currency in Circulation / Total Assets                          0.512579
# Linear Loss                                                     0.730931
#
#                                         Currency in Circulation / Total Assets  \
# Effective Federal Funds Rate (%)                                      0.512579
# Currency in Circulation / Total Assets                                1.000000
# Linear Loss                                                          -0.127413
#
#                                         Linear Loss
# Effective Federal Funds Rate (%)           0.730931
# Currency in Circulation / Total Assets    -0.127413
# Linear Loss                                1.000000
#                                         Effective Federal Funds Rate (%)  \
# Effective Federal Funds Rate (%)                                     NaN
# Currency in Circulation / Total Assets                      5.302200e-10
# Linear Loss                                                 8.119661e-23
#
#                                         Currency in Circulation / Total Assets  \
# Effective Federal Funds Rate (%)                                  5.302200e-10
# Currency in Circulation / Total Assets                                     NaN
# Linear Loss                                                       1.501743e-01
#
#                                          Linear Loss
# Effective Federal Funds Rate (%)        8.119661e-23
# Currency in Circulation / Total Assets  1.501743e-01
# Linear Loss                                      NaN
#                                         Effective Federal Funds Rate (%)  \
# Effective Federal Funds Rate (%)                                1.000000
# Currency in Circulation / Total Assets                          0.512579
# Unemployment Loss                                              -0.712867
# Inflation Loss                                                  0.428958
#
#                                         Currency in Circulation / Total Assets  \
# Effective Federal Funds Rate (%)                                      0.512579
# Currency in Circulation / Total Assets                                1.000000
# Unemployment Loss                                                     0.144737
# Inflation Loss                                                        0.080118
#
#                                         Unemployment Loss  Inflation Loss
# Effective Federal Funds Rate (%)                -0.712867        0.428958
# Currency in Circulation / Total Assets           0.144737        0.080118
# Unemployment Loss                                1.000000       -0.344377
# Inflation Loss                                  -0.344377        1.000000
#                                         Effective Federal Funds Rate (%)  \
# Effective Federal Funds Rate (%)                                     NaN
# Currency in Circulation / Total Assets                      5.302200e-10
# Unemployment Loss                                           2.646610e-21
# Inflation Loss                                              3.936268e-07
#
#                                         Currency in Circulation / Total Assets  \
# Effective Federal Funds Rate (%)                                  5.302200e-10
# Currency in Circulation / Total Assets                                     NaN
# Unemployment Loss                                                 1.017288e-01
# Inflation Loss                                                    3.667603e-01
#
#                                         Unemployment Loss  Inflation Loss
# Effective Federal Funds Rate (%)             2.646610e-21    3.936268e-07
# Currency in Circulation / Total Assets       1.017288e-01    3.667603e-01
# Unemployment Loss                                     NaN    6.435604e-05
# Inflation Loss                               6.435604e-05             NaN
#                                              Effective Federal Funds Rate Diff (%)  \
# Effective Federal Funds Rate Diff (%)                                     1.000000
# Currency in Circulation / Total Assets Diff                               0.732775
# Linear Loss Diff                                                          0.522931
#
#                                              Currency in Circulation / Total Assets Diff  \
# Effective Federal Funds Rate Diff (%)                                           0.732775
# Currency in Circulation / Total Assets Diff                                     1.000000
# Linear Loss Diff                                                                0.588867
#
#                                              Linear Loss Diff
# Effective Federal Funds Rate Diff (%)                0.522931
# Currency in Circulation / Total Assets Diff          0.588867
# Linear Loss Diff                                     1.000000
#                                              Effective Federal Funds Rate Diff (%)  \
# Effective Federal Funds Rate Diff (%)                                          NaN
# Currency in Circulation / Total Assets Diff                           5.600052e-23
# Linear Loss Diff                                                      2.052620e-10
#
#                                              Currency in Circulation / Total Assets Diff  \
# Effective Federal Funds Rate Diff (%)                                       5.600052e-23
# Currency in Circulation / Total Assets Diff                                          NaN
# Linear Loss Diff                                                            2.137850e-13
#
#                                              Linear Loss Diff
# Effective Federal Funds Rate Diff (%)            2.052620e-10
# Currency in Circulation / Total Assets Diff      2.137850e-13
# Linear Loss Diff                                          NaN
#                                              Effective Federal Funds Rate Diff (%)  \
# Effective Federal Funds Rate Diff (%)                                     1.000000
# Currency in Circulation / Total Assets Diff                               0.732775
# Unemployment Loss Diff                                                   -0.460767
# Inflation Loss Diff                                                       0.334206
#
#                                              Currency in Circulation / Total Assets Diff  \
# Effective Federal Funds Rate Diff (%)                                           0.732775
# Currency in Circulation / Total Assets Diff                                     1.000000
# Unemployment Loss Diff                                                         -0.529246
# Inflation Loss Diff                                                             0.355205
#
#                                              Unemployment Loss Diff  \
# Effective Federal Funds Rate Diff (%)                     -0.460767
# Currency in Circulation / Total Assets Diff               -0.529246
# Unemployment Loss Diff                                     1.000000
# Inflation Loss Diff                                       -0.190197
#
#                                              Inflation Loss Diff
# Effective Federal Funds Rate Diff (%)                   0.334206
# Currency in Circulation / Total Assets Diff             0.355205
# Unemployment Loss Diff                                 -0.190197
# Inflation Loss Diff                                     1.000000
#                                              Effective Federal Funds Rate Diff (%)  \
# Effective Federal Funds Rate Diff (%)                                          NaN
# Currency in Circulation / Total Assets Diff                           5.600052e-23
# Unemployment Loss Diff                                                3.914710e-08
# Inflation Loss Diff                                                   1.084747e-04
#
#                                              Currency in Circulation / Total Assets Diff  \
# Effective Federal Funds Rate Diff (%)                                       5.600052e-23
# Currency in Circulation / Total Assets Diff                                          NaN
# Unemployment Loss Diff                                                      1.132360e-10
# Inflation Loss Diff                                                         3.617886e-05
#
#                                              Unemployment Loss Diff  \
# Effective Federal Funds Rate Diff (%)                  3.914710e-08
# Currency in Circulation / Total Assets Diff            1.132360e-10
# Unemployment Loss Diff                                          NaN
# Inflation Loss Diff                                    3.085424e-02
#
#                                              Inflation Loss Diff
# Effective Federal Funds Rate Diff (%)                   0.000108
# Currency in Circulation / Total Assets Diff             0.000036
# Unemployment Loss Diff                                  0.030854
# Inflation Loss Diff                                          NaN

# %%
from statsmodels.tsa.api import VAR
diffs = ["", " Diff"]
for diff in diffs:
    plot_vars_dct = {0: ["Effective Federal Funds Rate" +diff + " (%)",
                         "Currency in Circulation / Total Assets" + diff,
                        "Linear Loss" + diff],
#                      1:["Currency in Circulation Growth Rate" +diff + " (%)",
#                         "Loss Function" + diff,
#                         "Effective Federal Funds Rate" +diff + " (%)",
#                         "Total Assets Growth Rate" +diff + " (%)"],
                     2:["Effective Federal Funds Rate" +diff + " (%)",
                        "Currency in Circulation / Total Assets" + diff,
                         "Unemployment Loss" + diff,
                        "Inflation Loss" + diff],

#                      3:["Currency in Circulation Growth Rate" +diff + " (%)",
#                         "Unemployment Loss Sq" + diff,
#                         "Inflation Loss Sq" + diff,
#                         "Effective Federal Funds Rate" +diff + " (%)",
#                         "Total Assets Growth Rate" +diff + " (%)"],
                    }
    for i in plot_vars_dct:
        var_data = data[plot_vars_dct[i]].dropna().loc["2008-10-31":]#.resample("Q").last()
        model = VAR(var_data)
        results = model.fit(12)
        print(results.summary())
#         irf = results.irf(24)
#         # irf.plot(orth=False)
#         for key in var_data.keys():
#             irf.plot(impulse=key)
#             irf.plot_cum_effects(orth=False, impulse = key)
# Out:
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Sat, 11, Sep, 2021
# Time:                     10:41:00
# --------------------------------------------------------------------
# No. of Equations:         3.00000    BIC:                   -15.1692
# Nobs:                     142.000    HQIC:                  -16.5408
# Log likelihood:           747.591    FPE:                2.65880e-08
# AIC:                     -17.4797    Det(Omega_mle):     1.32737e-08
# --------------------------------------------------------------------
# Results for equation Effective Federal Funds Rate (%)
# =============================================================================================================
#                                                 coefficient       std. error           t-stat            prob
# -------------------------------------------------------------------------------------------------------------
# const                                              0.290130         0.119614            2.426           0.015
# L1.Effective Federal Funds Rate (%)                1.395367         0.121886           11.448           0.000
# L1.Currency in Circulation / Total Assets          2.174529         2.594947            0.838           0.402
# L1.Linear Loss                                    -0.052154         0.023243           -2.244           0.025
# L2.Effective Federal Funds Rate (%)               -0.571266         0.197648           -2.890           0.004
# L2.Currency in Circulation / Total Assets         -5.664449         4.915370           -1.152           0.249
# L2.Linear Loss                                     0.063884         0.036976            1.728           0.084
# L3.Effective Federal Funds Rate (%)                0.207364         0.279311            0.742           0.458
# L3.Currency in Circulation / Total Assets          4.000177         5.165504            0.774           0.439
# L3.Linear Loss                                    -0.029865         0.037994           -0.786           0.432
# L4.Effective Federal Funds Rate (%)                0.130577         0.301029            0.434           0.664
# L4.Currency in Circulation / Total Assets         -5.941080         5.226616           -1.137           0.256
# L4.Linear Loss                                    -0.005878         0.035942           -0.164           0.870
# L5.Effective Federal Funds Rate (%)                0.220739         0.305298            0.723           0.470
# L5.Currency in Circulation / Total Assets         10.239313         5.006257            2.045           0.041
# L5.Linear Loss                                    -0.032556         0.034493           -0.944           0.345
# L6.Effective Federal Funds Rate (%)               -0.276326         0.312061           -0.885           0.376
# L6.Currency in Circulation / Total Assets         -7.776878         4.754620           -1.636           0.102
# L6.Linear Loss                                    -0.018474         0.033369           -0.554           0.580
# L7.Effective Federal Funds Rate (%)                0.583589         0.308862            1.889           0.059
# L7.Currency in Circulation / Total Assets          2.639466         5.077652            0.520           0.603
# L7.Linear Loss                                     0.046451         0.032739            1.419           0.156
# L8.Effective Federal Funds Rate (%)               -1.100564         0.312192           -3.525           0.000
# L8.Currency in Circulation / Total Assets         -0.627528         5.105925           -0.123           0.902
# L8.Linear Loss                                    -0.027309         0.032673           -0.836           0.403
# L9.Effective Federal Funds Rate (%)                1.070543         0.346392            3.091           0.002
# L9.Currency in Circulation / Total Assets         -0.038421         4.471392           -0.009           0.993
# L9.Linear Loss                                     0.037709         0.027996            1.347           0.178
# L10.Effective Federal Funds Rate (%)              -1.193765         0.369020           -3.235           0.001
# L10.Currency in Circulation / Total Assets        -0.313848         4.166283           -0.075           0.940
# L10.Linear Loss                                   -0.004145         0.027444           -0.151           0.880
# L11.Effective Federal Funds Rate (%)               0.892969         0.356032            2.508           0.012
# L11.Currency in Circulation / Total Assets        -0.852996         3.402106           -0.251           0.802
# L11.Linear Loss                                   -0.011732         0.020701           -0.567           0.571
# L12.Effective Federal Funds Rate (%)              -0.316920         0.189082           -1.676           0.094
# L12.Currency in Circulation / Total Assets         0.972503         1.745639            0.557           0.577
# L12.Linear Loss                                    0.009915         0.012063            0.822           0.411
# =============================================================================================================
#
# Results for equation Currency in Circulation / Total Assets
# =============================================================================================================
#                                                 coefficient       std. error           t-stat            prob
# -------------------------------------------------------------------------------------------------------------
# const                                              0.022482         0.006665            3.373           0.001
# L1.Effective Federal Funds Rate (%)                0.034324         0.006791            5.054           0.000
# L1.Currency in Circulation / Total Assets          1.741959         0.144587           12.048           0.000
# L1.Linear Loss                                    -0.004586         0.001295           -3.541           0.000
# L2.Effective Federal Funds Rate (%)               -0.049795         0.011013           -4.522           0.000
# L2.Currency in Circulation / Total Assets         -1.024684         0.273879           -3.741           0.000
# L2.Linear Loss                                     0.004698         0.002060            2.280           0.023
# L3.Effective Federal Funds Rate (%)                0.006705         0.015563            0.431           0.667
# L3.Currency in Circulation / Total Assets          0.270651         0.287816            0.940           0.347
# L3.Linear Loss                                    -0.001563         0.002117           -0.738           0.460
# L4.Effective Federal Funds Rate (%)               -0.000537         0.016773           -0.032           0.974
# L4.Currency in Circulation / Total Assets          0.224660         0.291221            0.771           0.440
# L4.Linear Loss                                    -0.002133         0.002003           -1.065           0.287
# L5.Effective Federal Funds Rate (%)                0.048685         0.017011            2.862           0.004
# L5.Currency in Circulation / Total Assets         -0.631646         0.278943           -2.264           0.024
# L5.Linear Loss                                     0.000520         0.001922            0.271           0.787
# L6.Effective Federal Funds Rate (%)               -0.033086         0.017388           -1.903           0.057
# L6.Currency in Circulation / Total Assets          0.934620         0.264922            3.528           0.000
# L6.Linear Loss                                    -0.003872         0.001859           -2.083           0.037
# L7.Effective Federal Funds Rate (%)                0.026127         0.017209            1.518           0.129
# L7.Currency in Circulation / Total Assets         -1.101057         0.282921           -3.892           0.000
# L7.Linear Loss                                     0.005411         0.001824            2.966           0.003
# L8.Effective Federal Funds Rate (%)               -0.019679         0.017395           -1.131           0.258
# L8.Currency in Circulation / Total Assets          0.577525         0.284496            2.030           0.042
# L8.Linear Loss                                    -0.001940         0.001820           -1.066           0.287
# L9.Effective Federal Funds Rate (%)               -0.007710         0.019301           -0.399           0.690
# L9.Currency in Circulation / Total Assets          0.110854         0.249141            0.445           0.656
# L9.Linear Loss                                    -0.000319         0.001560           -0.204           0.838
# L10.Effective Federal Funds Rate (%)               0.009122         0.020561            0.444           0.657
# L10.Currency in Circulation / Total Assets        -0.506194         0.232141           -2.181           0.029
# L10.Linear Loss                                    0.002106         0.001529            1.377           0.168
# L11.Effective Federal Funds Rate (%)              -0.009271         0.019838           -0.467           0.640
# L11.Currency in Circulation / Total Assets         0.422996         0.189561            2.231           0.026
# L11.Linear Loss                                   -0.001436         0.001153           -1.245           0.213
# L12.Effective Federal Funds Rate (%)               0.002791         0.010535            0.265           0.791
# L12.Currency in Circulation / Total Assets        -0.132650         0.097265           -1.364           0.173
# L12.Linear Loss                                    0.000264         0.000672            0.393           0.694
# =============================================================================================================
#
# Results for equation Linear Loss
# =============================================================================================================
#                                                 coefficient       std. error           t-stat            prob
# -------------------------------------------------------------------------------------------------------------
# const                                              2.256249         0.656507            3.437           0.001
# L1.Effective Federal Funds Rate (%)                6.257485         0.668977            9.354           0.000
# L1.Currency in Circulation / Total Assets          5.452750        14.242517            0.383           0.702
# L1.Linear Loss                                     0.915657         0.127572            7.178           0.000
# L2.Effective Federal Funds Rate (%)              -11.076586         1.084801          -10.211           0.000
# L2.Currency in Circulation / Total Assets        -32.095778        26.978296           -1.190           0.234
# L2.Linear Loss                                     0.110265         0.202946            0.543           0.587
# L3.Effective Federal Funds Rate (%)                5.176890         1.533012            3.377           0.001
# L3.Currency in Circulation / Total Assets         32.580464        28.351167            1.149           0.250
# L3.Linear Loss                                    -0.093775         0.208532           -0.450           0.653
# L4.Effective Federal Funds Rate (%)               -2.589571         1.652217           -1.567           0.117
# L4.Currency in Circulation / Total Assets          1.383546        28.686587            0.048           0.962
# L4.Linear Loss                                    -0.288893         0.197271           -1.464           0.143
# L5.Effective Federal Funds Rate (%)                5.780518         1.675648            3.450           0.001
# L5.Currency in Circulation / Total Assets        -42.035749        27.477131           -1.530           0.126
# L5.Linear Loss                                     0.069468         0.189315            0.367           0.714
# L6.Effective Federal Funds Rate (%)               -2.756463         1.712765           -1.609           0.108
# L6.Currency in Circulation / Total Assets         72.041590        26.096008            2.761           0.006
# L6.Linear Loss                                    -0.150306         0.183147           -0.821           0.412
# L7.Effective Federal Funds Rate (%)               -0.723215         1.695205           -0.427           0.670
# L7.Currency in Circulation / Total Assets        -63.868570        27.868986           -2.292           0.022
# L7.Linear Loss                                     0.022705         0.179689            0.126           0.899
# L8.Effective Federal Funds Rate (%)                4.627662         1.713484            2.701           0.007
# L8.Currency in Circulation / Total Assets         18.924477        28.024164            0.675           0.499
# L8.Linear Loss                                    -0.026575         0.179327           -0.148           0.882
# L9.Effective Federal Funds Rate (%)               -4.825036         1.901190           -2.538           0.011
# L9.Currency in Circulation / Total Assets          0.668064        24.541496            0.027           0.978
# L9.Linear Loss                                     0.145875         0.153659            0.949           0.342
# L10.Effective Federal Funds Rate (%)               1.316105         2.025386            0.650           0.516
# L10.Currency in Circulation / Total Assets        -9.684656        22.866884           -0.424           0.672
# L10.Linear Loss                                    0.043023         0.150629            0.286           0.775
# L11.Effective Federal Funds Rate (%)              -0.943719         1.954104           -0.483           0.629
# L11.Currency in Circulation / Total Assets         7.206471        18.672658            0.386           0.700
# L11.Linear Loss                                   -0.073763         0.113618           -0.649           0.516
# L12.Effective Federal Funds Rate (%)               0.623413         1.037789            0.601           0.548
# L12.Currency in Circulation / Total Assets        -2.470249         9.581040           -0.258           0.797
# L12.Linear Loss                                   -0.002566         0.066206           -0.039           0.969
# =============================================================================================================
#
# Correlation matrix of residuals
#                                           Effective Federal Funds Rate (%)  Currency in Circulation / Total Assets  Linear Loss
# Effective Federal Funds Rate (%)                                  1.000000                                0.628652     0.441329
# Currency in Circulation / Total Assets                            0.628652                                1.000000     0.655931
# Linear Loss                                                       0.441329                                0.655931     1.000000
#
#
#
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Sat, 11, Sep, 2021
# Time:                     10:41:00
# --------------------------------------------------------------------
# No. of Equations:         4.00000    BIC:                   -17.8198
# Nobs:                     142.000    HQIC:                  -20.2418
# Log likelihood:           944.918    FPE:                3.47062e-10
# AIC:                     -21.8996    Det(Omega_mle):     1.06030e-10
# --------------------------------------------------------------------
# Results for equation Effective Federal Funds Rate (%)
# =============================================================================================================
#                                                 coefficient       std. error           t-stat            prob
# -------------------------------------------------------------------------------------------------------------
# const                                              0.280797         0.156016            1.800           0.072
# L1.Effective Federal Funds Rate (%)                1.320745         0.125266           10.544           0.000
# L1.Currency in Circulation / Total Assets          1.706293         2.825129            0.604           0.546
# L1.Unemployment Loss                               0.075937         0.028224            2.690           0.007
# L1.Inflation Loss                                  0.052290         0.074848            0.699           0.485
# L2.Effective Federal Funds Rate (%)               -0.392214         0.209744           -1.870           0.061
# L2.Currency in Circulation / Total Assets         -5.403982         4.957005           -1.090           0.276
# L2.Unemployment Loss                              -0.085426         0.040661           -2.101           0.036
# L2.Inflation Loss                                 -0.073573         0.104638           -0.703           0.482
# L3.Effective Federal Funds Rate (%)                0.025133         0.295497            0.085           0.932
# L3.Currency in Circulation / Total Assets          2.926162         5.092889            0.575           0.566
# L3.Unemployment Loss                               0.018677         0.041006            0.455           0.649
# L3.Inflation Loss                                  0.016424         0.103575            0.159           0.874
# L4.Effective Federal Funds Rate (%)                0.155482         0.307572            0.506           0.613
# L4.Currency in Circulation / Total Assets         -4.586167         5.185807           -0.884           0.376
# L4.Unemployment Loss                               0.015411         0.040788            0.378           0.706
# L4.Inflation Loss                                  0.035887         0.116371            0.308           0.758
# L5.Effective Federal Funds Rate (%)                0.220000         0.310605            0.708           0.479
# L5.Currency in Circulation / Total Assets         11.602848         4.955575            2.341           0.019
# L5.Unemployment Loss                               0.077107         0.038843            1.985           0.047
# L5.Inflation Loss                                  0.059059         0.117218            0.504           0.614
# L6.Effective Federal Funds Rate (%)               -0.097205         0.319432           -0.304           0.761
# L6.Currency in Circulation / Total Assets         -9.201028         4.790723           -1.921           0.055
# L6.Unemployment Loss                               0.008728         0.038489            0.227           0.821
# L6.Inflation Loss                                  0.090455         0.121878            0.742           0.458
# L7.Effective Federal Funds Rate (%)                0.388861         0.318516            1.221           0.222
# L7.Currency in Circulation / Total Assets          4.585736         5.166832            0.888           0.375
# L7.Unemployment Loss                              -0.034428         0.037711           -0.913           0.361
# L7.Inflation Loss                                 -0.103596         0.124144           -0.834           0.404
# L8.Effective Federal Funds Rate (%)               -0.899122         0.318841           -2.820           0.005
# L8.Currency in Circulation / Total Assets         -3.316259         5.143506           -0.645           0.519
# L8.Unemployment Loss                              -0.002782         0.036514           -0.076           0.939
# L8.Inflation Loss                                 -0.100261         0.123220           -0.814           0.416
# L9.Effective Federal Funds Rate (%)                0.954433         0.350274            2.725           0.006
# L9.Currency in Circulation / Total Assets          0.398908         4.483449            0.089           0.929
# L9.Unemployment Loss                              -0.022937         0.030196           -0.760           0.447
# L9.Inflation Loss                                  0.007483         0.125703            0.060           0.953
# L10.Effective Federal Funds Rate (%)              -0.980626         0.372975           -2.629           0.009
# L10.Currency in Circulation / Total Assets        -1.197320         4.175192           -0.287           0.774
# L10.Unemployment Loss                             -0.013796         0.029010           -0.476           0.634
# L10.Inflation Loss                                 0.116698         0.123402            0.946           0.344
# L11.Effective Federal Funds Rate (%)               0.555599         0.368643            1.507           0.132
# L11.Currency in Circulation / Total Assets         0.066456         3.470117            0.019           0.985
# L11.Unemployment Loss                              0.006039         0.023810            0.254           0.800
# L11.Inflation Loss                                -0.176844         0.123406           -1.433           0.152
# L12.Effective Federal Funds Rate (%)              -0.197939         0.207267           -0.955           0.340
# L12.Currency in Circulation / Total Assets         0.734664         1.841217            0.399           0.690
# L12.Unemployment Loss                             -0.006928         0.015718           -0.441           0.659
# L12.Inflation Loss                                 0.121910         0.086291            1.413           0.158
# =============================================================================================================
#
# Results for equation Currency in Circulation / Total Assets
# =============================================================================================================
#                                                 coefficient       std. error           t-stat            prob
# -------------------------------------------------------------------------------------------------------------
# const                                              0.028503         0.008623            3.306           0.001
# L1.Effective Federal Funds Rate (%)                0.030379         0.006923            4.388           0.000
# L1.Currency in Circulation / Total Assets          1.670642         0.156136           10.700           0.000
# L1.Unemployment Loss                               0.005147         0.001560            3.300           0.001
# L1.Inflation Loss                                  0.000533         0.004137            0.129           0.898
# L2.Effective Federal Funds Rate (%)               -0.043952         0.011592           -3.792           0.000
# L2.Currency in Circulation / Total Assets         -0.988941         0.273959           -3.610           0.000
# L2.Unemployment Loss                              -0.005557         0.002247           -2.473           0.013
# L2.Inflation Loss                                 -0.004453         0.005783           -0.770           0.441
# L3.Effective Federal Funds Rate (%)                0.001814         0.016331            0.111           0.912
# L3.Currency in Circulation / Total Assets          0.259994         0.281469            0.924           0.356
# L3.Unemployment Loss                               0.001339         0.002266            0.591           0.554
# L3.Inflation Loss                                  0.002630         0.005724            0.460           0.646
# L4.Effective Federal Funds Rate (%)               -0.000159         0.016999           -0.009           0.993
# L4.Currency in Circulation / Total Assets          0.241180         0.286604            0.842           0.400
# L4.Unemployment Loss                               0.002885         0.002254            1.280           0.201
# L4.Inflation Loss                                 -0.001973         0.006431           -0.307           0.759
# L5.Effective Federal Funds Rate (%)                0.052657         0.017166            3.067           0.002
# L5.Currency in Circulation / Total Assets         -0.532198         0.273880           -1.943           0.052
# L5.Unemployment Loss                               0.001453         0.002147            0.677           0.498
# L5.Inflation Loss                                  0.010376         0.006478            1.602           0.109
# L6.Effective Federal Funds Rate (%)               -0.031022         0.017654           -1.757           0.079
# L6.Currency in Circulation / Total Assets          0.836804         0.264769            3.161           0.002
# L6.Unemployment Loss                               0.003103         0.002127            1.459           0.145
# L6.Inflation Loss                                 -0.003920         0.006736           -0.582           0.561
# L7.Effective Federal Funds Rate (%)                0.021841         0.017603            1.241           0.215
# L7.Currency in Circulation / Total Assets         -0.939022         0.285555           -3.288           0.001
# L7.Unemployment Loss                              -0.003745         0.002084           -1.797           0.072
# L7.Inflation Loss                                  0.001799         0.006861            0.262           0.793
# L8.Effective Federal Funds Rate (%)               -0.010529         0.017621           -0.598           0.550
# L8.Currency in Circulation / Total Assets          0.426094         0.284266            1.499           0.134
# L8.Unemployment Loss                               0.000853         0.002018            0.423           0.672
# L8.Inflation Loss                                 -0.004381         0.006810           -0.643           0.520
# L9.Effective Federal Funds Rate (%)               -0.009649         0.019359           -0.498           0.618
# L9.Currency in Circulation / Total Assets          0.086168         0.247787            0.348           0.728
# L9.Unemployment Loss                               0.000587         0.001669            0.352           0.725
# L9.Inflation Loss                                 -0.001083         0.006947           -0.156           0.876
# L10.Effective Federal Funds Rate (%)               0.013492         0.020613            0.655           0.513
# L10.Currency in Circulation / Total Assets        -0.504196         0.230750           -2.185           0.029
# L10.Unemployment Loss                             -0.003636         0.001603           -2.268           0.023
# L10.Inflation Loss                                 0.001014         0.006820            0.149           0.882
# L11.Effective Federal Funds Rate (%)              -0.024866         0.020374           -1.221           0.222
# L11.Currency in Circulation / Total Assets         0.434083         0.191783            2.263           0.024
# L11.Unemployment Loss                              0.001210         0.001316            0.920           0.358
# L11.Inflation Loss                                -0.007942         0.006820           -1.165           0.244
# L12.Effective Federal Funds Rate (%)               0.009459         0.011455            0.826           0.409
# L12.Currency in Circulation / Total Assets        -0.146342         0.101759           -1.438           0.150
# L12.Unemployment Loss                              0.000093         0.000869            0.107           0.915
# L12.Inflation Loss                                 0.006333         0.004769            1.328           0.184
# =============================================================================================================
#
# Results for equation Unemployment Loss
# =============================================================================================================
#                                                 coefficient       std. error           t-stat            prob
# -------------------------------------------------------------------------------------------------------------
# const                                             -0.676334         0.759717           -0.890           0.373
# L1.Effective Federal Funds Rate (%)               -5.208458         0.609980           -8.539           0.000
# L1.Currency in Circulation / Total Assets        -22.876420        13.756916           -1.663           0.096
# L1.Unemployment Loss                               0.737162         0.137438            5.364           0.000
# L1.Inflation Loss                                 -0.478606         0.364473           -1.313           0.189
# L2.Effective Federal Funds Rate (%)                9.084287         1.021345            8.894           0.000
# L2.Currency in Circulation / Total Assets         54.169440        24.138049            2.244           0.025
# L2.Unemployment Loss                               0.369850         0.197997            1.868           0.062
# L2.Inflation Loss                                  1.145984         0.509533            2.249           0.025
# L3.Effective Federal Funds Rate (%)               -3.803989         1.438915           -2.644           0.008
# L3.Currency in Circulation / Total Assets        -34.522491        24.799734           -1.392           0.164
# L3.Unemployment Loss                              -0.011677         0.199676           -0.058           0.953
# L3.Inflation Loss                                 -0.640655         0.504358           -1.270           0.204
# L4.Effective Federal Funds Rate (%)                2.473070         1.497717            1.651           0.099
# L4.Currency in Circulation / Total Assets        -11.653713        25.252196           -0.461           0.644
# L4.Unemployment Loss                              -0.480030         0.198616           -2.417           0.016
# L4.Inflation Loss                                  0.050326         0.566668            0.089           0.929
# L5.Effective Federal Funds Rate (%)               -6.238674         1.512487           -4.125           0.000
# L5.Currency in Circulation / Total Assets         39.958895        24.131087            1.656           0.098
# L5.Unemployment Loss                              -0.051115         0.189146           -0.270           0.787
# L5.Inflation Loss                                 -1.419089         0.570790           -2.486           0.013
# L6.Effective Federal Funds Rate (%)                3.582383         1.555470            2.303           0.021
# L6.Currency in Circulation / Total Assets        -64.004772        23.328339           -2.744           0.006
# L6.Unemployment Loss                              -0.012461         0.187422           -0.066           0.947
# L6.Inflation Loss                                  1.181803         0.593485            1.991           0.046
# L7.Effective Federal Funds Rate (%)                0.202695         1.551006            0.131           0.896
# L7.Currency in Circulation / Total Assets         64.900526        25.159798            2.580           0.010
# L7.Unemployment Loss                               0.076374         0.183632            0.416           0.677
# L7.Inflation Loss                                  0.147716         0.604518            0.244           0.807
# L8.Effective Federal Funds Rate (%)               -3.921425         1.552590           -2.526           0.012
# L8.Currency in Circulation / Total Assets        -21.770412        25.046213           -0.869           0.385
# L8.Unemployment Loss                               0.073717         0.177803            0.415           0.678
# L8.Inflation Loss                                  0.808968         0.600016            1.348           0.178
# L9.Effective Federal Funds Rate (%)                3.803217         1.705652            2.230           0.026
# L9.Currency in Circulation / Total Assets          9.978977        21.832077            0.457           0.648
# L9.Unemployment Loss                               0.141584         0.147037            0.963           0.336
# L9.Inflation Loss                                 -0.419924         0.612110           -0.686           0.493
# L10.Effective Federal Funds Rate (%)              -1.196284         1.816193           -0.659           0.510
# L10.Currency in Circulation / Total Assets         4.282328        20.331021            0.211           0.833
# L10.Unemployment Loss                              0.114892         0.141265            0.813           0.416
# L10.Inflation Loss                                -0.173554         0.600902           -0.289           0.773
# L11.Effective Federal Funds Rate (%)               2.633091         1.795100            1.467           0.142
# L11.Currency in Circulation / Total Assets       -21.398216        16.897674           -1.266           0.205
# L11.Unemployment Loss                             -0.197726         0.115944           -1.705           0.088
# L11.Inflation Loss                                -0.279386         0.600924           -0.465           0.642
# L12.Effective Federal Funds Rate (%)              -1.858824         1.009281           -1.842           0.066
# L12.Currency in Circulation / Total Assets        10.247200         8.965775            1.143           0.253
# L12.Unemployment Loss                              0.018704         0.076537            0.244           0.807
# L12.Inflation Loss                                -0.147029         0.420194           -0.350           0.726
# =============================================================================================================
#
# Results for equation Inflation Loss
# =============================================================================================================
#                                                 coefficient       std. error           t-stat            prob
# -------------------------------------------------------------------------------------------------------------
# const                                              0.610466         0.217418            2.808           0.005
# L1.Effective Federal Funds Rate (%)                0.749873         0.174565            4.296           0.000
# L1.Currency in Circulation / Total Assets         -4.496246         3.936988           -1.142           0.253
# L1.Unemployment Loss                              -0.022917         0.039332           -0.583           0.560
# L1.Inflation Loss                                  1.050772         0.104306           10.074           0.000
# L2.Effective Federal Funds Rate (%)               -1.135414         0.292291           -3.885           0.000
# L2.Currency in Circulation / Total Assets          1.723088         6.907887            0.249           0.803
# L2.Unemployment Loss                              -0.036880         0.056663           -0.651           0.515
# L2.Inflation Loss                                 -0.176963         0.145819           -1.214           0.225
# L3.Effective Federal Funds Rate (%)                0.372782         0.411792            0.905           0.365
# L3.Currency in Circulation / Total Assets          5.057769         7.097249            0.713           0.476
# L3.Unemployment Loss                               0.049773         0.057144            0.871           0.384
# L3.Inflation Loss                                  0.008159         0.144338            0.057           0.955
# L4.Effective Federal Funds Rate (%)                0.009006         0.428620            0.021           0.983
# L4.Currency in Circulation / Total Assets         -5.732379         7.226736           -0.793           0.428
# L4.Unemployment Loss                               0.041043         0.056840            0.722           0.470
# L4.Inflation Loss                                  0.148249         0.162170            0.914           0.361
# L5.Effective Federal Funds Rate (%)                0.448719         0.432847            1.037           0.300
# L5.Currency in Circulation / Total Assets          7.425494         6.905894            1.075           0.282
# L5.Unemployment Loss                               0.015332         0.054130            0.283           0.777
# L5.Inflation Loss                                 -0.104228         0.163350           -0.638           0.523
# L6.Effective Federal Funds Rate (%)               -0.235511         0.445148           -0.529           0.597
# L6.Currency in Circulation / Total Assets         -7.778211         6.676162           -1.165           0.244
# L6.Unemployment Loss                              -0.108033         0.053637           -2.014           0.044
# L6.Inflation Loss                                 -0.220844         0.169845           -1.300           0.194
# L7.Effective Federal Funds Rate (%)               -0.250436         0.443871           -0.564           0.573
# L7.Currency in Circulation / Total Assets          7.866693         7.200293            1.093           0.275
# L7.Unemployment Loss                               0.094304         0.052552            1.794           0.073
# L7.Inflation Loss                                 -0.120522         0.173003           -0.697           0.486
# L8.Effective Federal Funds Rate (%)                0.602833         0.444324            1.357           0.175
# L8.Currency in Circulation / Total Assets         -8.997889         7.167787           -1.255           0.209
# L8.Unemployment Loss                              -0.033478         0.050884           -0.658           0.511
# L8.Inflation Loss                                  0.263723         0.171714            1.536           0.125
# L9.Effective Federal Funds Rate (%)               -0.513578         0.488128           -1.052           0.293
# L9.Currency in Circulation / Total Assets          4.249304         6.247958            0.680           0.496
# L9.Unemployment Loss                               0.000763         0.042079            0.018           0.986
# L9.Inflation Loss                                  0.087732         0.175175            0.501           0.616
# L10.Effective Federal Funds Rate (%)              -0.236402         0.519763           -0.455           0.649
# L10.Currency in Circulation / Total Assets         0.630881         5.818382            0.108           0.914
# L10.Unemployment Loss                             -0.070146         0.040428           -1.735           0.083
# L10.Inflation Loss                                -0.257718         0.171968           -1.499           0.134
# L11.Effective Federal Funds Rate (%)              -0.120667         0.513726           -0.235           0.814
# L11.Currency in Circulation / Total Assets        -3.108985         4.835818           -0.643           0.520
# L11.Unemployment Loss                              0.070738         0.033181            2.132           0.033
# L11.Inflation Loss                                -0.004491         0.171974           -0.026           0.979
# L12.Effective Federal Funds Rate (%)               0.524858         0.288839            1.817           0.069
# L12.Currency in Circulation / Total Assets         1.554562         2.565848            0.606           0.545
# L12.Unemployment Loss                              0.044344         0.021903            2.024           0.043
# L12.Inflation Loss                                 0.048109         0.120252            0.400           0.689
# =============================================================================================================
#
# Correlation matrix of residuals
#                                           Effective Federal Funds Rate (%)  Currency in Circulation / Total Assets  Unemployment Loss  Inflation Loss
# Effective Federal Funds Rate (%)                                  1.000000                                0.573282          -0.384687        0.306991
# Currency in Circulation / Total Assets                            0.573282                                1.000000          -0.668753        0.238984
# Unemployment Loss                                                -0.384687                               -0.668753           1.000000       -0.160474
# Inflation Loss                                                    0.306991                                0.238984          -0.160474        1.000000
#
#
#
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Sat, 11, Sep, 2021
# Time:                     10:41:00
# --------------------------------------------------------------------
# No. of Equations:         3.00000    BIC:                   -11.7193
# Nobs:                     142.000    HQIC:                  -13.0910
# Log likelihood:           502.654    FPE:                8.37385e-07
# AIC:                     -14.0299    Det(Omega_mle):     4.18053e-07
# --------------------------------------------------------------------
# Results for equation Effective Federal Funds Rate Diff (%)
# ==================================================================================================================
#                                                      coefficient       std. error           t-stat            prob
# ------------------------------------------------------------------------------------------------------------------
# const                                                   0.004952         0.010455            0.474           0.636
# L1.Effective Federal Funds Rate Diff (%)                1.399831         0.096249           14.544           0.000
# L1.Currency in Circulation / Total Assets Diff         -0.648181         0.799692           -0.811           0.418
# L1.Linear Loss Diff                                    -0.025028         0.013741           -1.821           0.069
# L2.Effective Federal Funds Rate Diff (%)               -0.543965         0.174854           -3.111           0.002
# L2.Currency in Circulation / Total Assets Diff          0.562312         1.287547            0.437           0.662
# L2.Linear Loss Diff                                     0.017013         0.020439            0.832           0.405
# L3.Effective Federal Funds Rate Diff (%)                0.090387         0.256913            0.352           0.725
# L3.Currency in Circulation / Total Assets Diff         -0.481597         1.263457           -0.381           0.703
# L3.Linear Loss Diff                                     0.019068         0.020134            0.947           0.344
# L4.Effective Federal Funds Rate Diff (%)                0.065190         0.274851            0.237           0.813
# L4.Currency in Circulation / Total Assets Diff          0.216505         0.962798            0.225           0.822
# L4.Linear Loss Diff                                    -0.088508         0.021233           -4.168           0.000
# L5.Effective Federal Funds Rate Diff (%)                0.766388         0.275061            2.786           0.005
# L5.Currency in Circulation / Total Assets Diff         -1.442660         0.852843           -1.692           0.091
# L5.Linear Loss Diff                                     0.065891         0.022822            2.887           0.004
# L6.Effective Federal Funds Rate Diff (%)               -0.845981         0.287983           -2.938           0.003
# L6.Currency in Circulation / Total Assets Diff          0.826167         0.857640            0.963           0.335
# L6.Linear Loss Diff                                    -0.038479         0.023343           -1.648           0.099
# L7.Effective Federal Funds Rate Diff (%)                0.639576         0.299828            2.133           0.033
# L7.Currency in Circulation / Total Assets Diff         -1.039138         0.878588           -1.183           0.237
# L7.Linear Loss Diff                                     0.031174         0.020519            1.519           0.129
# L8.Effective Federal Funds Rate Diff (%)               -0.721653         0.273342           -2.640           0.008
# L8.Currency in Circulation / Total Assets Diff          1.170295         0.804928            1.454           0.146
# L8.Linear Loss Diff                                     0.010202         0.020888            0.488           0.625
# L9.Effective Federal Funds Rate Diff (%)                0.278159         0.247498            1.124           0.261
# L9.Currency in Circulation / Total Assets Diff          0.539215         0.777702            0.693           0.488
# L9.Linear Loss Diff                                     0.024429         0.022029            1.109           0.267
# L10.Effective Federal Funds Rate Diff (%)              -0.301717         0.325975           -0.926           0.355
# L10.Currency in Circulation / Total Assets Diff        -0.723687         0.839327           -0.862           0.389
# L10.Linear Loss Diff                                    0.003965         0.018906            0.210           0.834
# L11.Effective Federal Funds Rate Diff (%)               0.138843         0.303413            0.458           0.647
# L11.Currency in Circulation / Total Assets Diff         0.965678         0.794433            1.216           0.224
# L11.Linear Loss Diff                                   -0.065483         0.015067           -4.346           0.000
# L12.Effective Federal Funds Rate Diff (%)              -0.005385         0.159945           -0.034           0.973
# L12.Currency in Circulation / Total Assets Diff        -0.346850         0.494273           -0.702           0.483
# L12.Linear Loss Diff                                    0.041128         0.012213            3.368           0.001
# ==================================================================================================================
#
# Results for equation Currency in Circulation / Total Assets Diff
# ==================================================================================================================
#                                                      coefficient       std. error           t-stat            prob
# ------------------------------------------------------------------------------------------------------------------
# const                                                  -0.001544         0.001384           -1.116           0.265
# L1.Effective Federal Funds Rate Diff (%)               -0.007947         0.012744           -0.624           0.533
# L1.Currency in Circulation / Total Assets Diff          1.338422         0.105880           12.641           0.000
# L1.Linear Loss Diff                                     0.000776         0.001819            0.426           0.670
# L2.Effective Federal Funds Rate Diff (%)                0.012407         0.023151            0.536           0.592
# L2.Currency in Circulation / Total Assets Diff         -0.775934         0.170473           -4.552           0.000
# L2.Linear Loss Diff                                    -0.002003         0.002706           -0.740           0.459
# L3.Effective Federal Funds Rate Diff (%)               -0.034399         0.034016           -1.011           0.312
# L3.Currency in Circulation / Total Assets Diff          0.442823         0.167283            2.647           0.008
# L3.Linear Loss Diff                                     0.005022         0.002666            1.884           0.060
# L4.Effective Federal Funds Rate Diff (%)               -0.001516         0.036391           -0.042           0.967
# L4.Currency in Circulation / Total Assets Diff          0.002252         0.127476            0.018           0.986
# L4.Linear Loss Diff                                    -0.005771         0.002811           -2.053           0.040
# L5.Effective Federal Funds Rate Diff (%)                0.097086         0.036418            2.666           0.008
# L5.Currency in Circulation / Total Assets Diff         -0.121780         0.112917           -1.078           0.281
# L5.Linear Loss Diff                                    -0.005603         0.003022           -1.854           0.064
# L6.Effective Federal Funds Rate Diff (%)                0.004347         0.038129            0.114           0.909
# L6.Currency in Circulation / Total Assets Diff         -0.240876         0.113553           -2.121           0.034
# L6.Linear Loss Diff                                     0.009441         0.003091            3.055           0.002
# L7.Effective Federal Funds Rate Diff (%)               -0.074341         0.039698           -1.873           0.061
# L7.Currency in Circulation / Total Assets Diff          0.211226         0.116326            1.816           0.069
# ...
# L7.Currency in Circulation / Total Assets Diff          0.232855         0.132542            1.757           0.079
# L7.Unemployment Loss Diff                               0.014593         0.003192            4.572           0.000
# L7.Inflation Loss Diff                                 -0.019491         0.011413           -1.708           0.088
# L8.Effective Federal Funds Rate Diff (%)                0.201131         0.036926            5.447           0.000
# L8.Currency in Circulation / Total Assets Diff         -0.575933         0.118858           -4.846           0.000
# L8.Unemployment Loss Diff                              -0.012650         0.003293           -3.842           0.000
# L8.Inflation Loss Diff                                  0.026961         0.011467            2.351           0.019
# L9.Effective Federal Funds Rate Diff (%)               -0.291117         0.033971           -8.570           0.000
# L9.Currency in Circulation / Total Assets Diff          0.650994         0.116861            5.571           0.000
# L9.Unemployment Loss Diff                               0.002983         0.003406            0.876           0.381
# L9.Inflation Loss Diff                                 -0.014264         0.011738           -1.215           0.224
# L10.Effective Federal Funds Rate Diff (%)               0.191567         0.044699            4.286           0.000
# L10.Currency in Circulation / Total Assets Diff        -0.367157         0.126348           -2.906           0.004
# L10.Unemployment Loss Diff                             -0.006796         0.002996           -2.268           0.023
# L10.Inflation Loss Diff                                 0.015471         0.011856            1.305           0.192
# L11.Effective Federal Funds Rate Diff (%)              -0.166328         0.042684           -3.897           0.000
# L11.Currency in Circulation / Total Assets Diff         0.370835         0.120063            3.089           0.002
# L11.Unemployment Loss Diff                              0.005193         0.002377            2.185           0.029
# L11.Inflation Loss Diff                                -0.011788         0.011939           -0.987           0.323
# L12.Effective Federal Funds Rate Diff (%)               0.078999         0.023298            3.391           0.001
# L12.Currency in Circulation / Total Assets Diff        -0.136504         0.075741           -1.802           0.072
# L12.Unemployment Loss Diff                             -0.001405         0.002016           -0.697           0.486
# L12.Inflation Loss Diff                                 0.003172         0.008210            0.386           0.699
# ==================================================================================================================
#
# Results for equation Unemployment Loss Diff
# ==================================================================================================================
#                                                      coefficient       std. error           t-stat            prob
# ------------------------------------------------------------------------------------------------------------------
# const                                                  -0.048370         0.066513           -0.727           0.467
# L1.Effective Federal Funds Rate Diff (%)               -7.326844         0.590875          -12.400           0.000
# L1.Currency in Circulation / Total Assets Diff         14.995572         4.994934            3.002           0.003
# L1.Unemployment Loss Diff                               1.076662         0.104232           10.329           0.000
# L1.Inflation Loss Diff                                 -0.626664         0.371854           -1.685           0.092
# L2.Effective Federal Funds Rate Diff (%)               13.292871         1.118706           11.882           0.000
# L2.Currency in Circulation / Total Assets Diff        -26.472564         8.155474           -3.246           0.001
# L2.Unemployment Loss Diff                              -0.041253         0.155919           -0.265           0.791
# L2.Inflation Loss Diff                                  1.983752         0.507383            3.910           0.000
# L3.Effective Federal Funds Rate Diff (%)               -7.835858         1.700253           -4.609           0.000
# L3.Currency in Circulation / Total Assets Diff          8.569355         8.398884            1.020           0.308
# L3.Unemployment Loss Diff                               0.036995         0.157283            0.235           0.814
# L3.Inflation Loss Diff                                 -1.440310         0.540700           -2.664           0.008
# L4.Effective Federal Funds Rate Diff (%)                3.969929         1.848182            2.148           0.032
# L4.Currency in Circulation / Total Assets Diff         -2.115839         6.734430           -0.314           0.753
# L4.Unemployment Loss Diff                              -0.452783         0.159671           -2.836           0.005
# L4.Inflation Loss Diff                                 -0.040640         0.560350           -0.073           0.942
# L5.Effective Federal Funds Rate Diff (%)               -5.527985         1.850375           -2.987           0.003
# L5.Currency in Circulation / Total Assets Diff         10.848649         5.907846            1.836           0.066
# L5.Unemployment Loss Diff                               0.240686         0.161187            1.493           0.135
# L5.Inflation Loss Diff                                 -0.895954         0.559604           -1.601           0.109
# L6.Effective Federal Funds Rate Diff (%)                2.471290         1.890397            1.307           0.191
# L6.Currency in Circulation / Total Assets Diff         -2.056903         5.820917           -0.353           0.724
# L6.Unemployment Loss Diff                              -0.039520         0.164621           -0.240           0.810
# L6.Inflation Loss Diff                                  1.874285         0.551142            3.401           0.001
# L7.Effective Federal Funds Rate Diff (%)                1.072196         1.907846            0.562           0.574
# L7.Currency in Circulation / Total Assets Diff         -6.000991         6.006687           -0.999           0.318
# L7.Unemployment Loss Diff                               0.128787         0.144663            0.890           0.373
# L7.Inflation Loss Diff                                 -0.903702         0.517226           -1.747           0.081
# L8.Effective Federal Funds Rate Diff (%)               -0.835952         1.673472           -0.500           0.617
# L8.Currency in Circulation / Total Assets Diff          7.189456         5.386542            1.335           0.182
# L8.Unemployment Loss Diff                               0.159060         0.149220            1.066           0.286
# L8.Inflation Loss Diff                                  0.761627         0.519658            1.466           0.143
# L9.Effective Federal Funds Rate Diff (%)                1.685651         1.539515            1.095           0.274
# L9.Currency in Circulation / Total Assets Diff         -8.255165         5.296047           -1.559           0.119
# L9.Unemployment Loss Diff                              -0.233061         0.154339           -1.510           0.131
# L9.Inflation Loss Diff                                 -0.603284         0.531960           -1.134           0.257
# L10.Effective Federal Funds Rate Diff (%)              -1.201405         2.025707           -0.593           0.553
# L10.Currency in Circulation / Total Assets Diff         7.780412         5.725995            1.359           0.174
# L10.Unemployment Loss Diff                              0.218837         0.135796            1.612           0.107
# L10.Inflation Loss Diff                                -0.091610         0.537307           -0.170           0.865
# L11.Effective Federal Funds Rate Diff (%)               1.608706         1.934419            0.832           0.406
# L11.Currency in Circulation / Total Assets Diff       -13.562098         5.441130           -2.493           0.013
# L11.Unemployment Loss Diff                             -0.316344         0.107713           -2.937           0.003
# L11.Inflation Loss Diff                                 0.102926         0.541074            0.190           0.849
# L12.Effective Federal Funds Rate Diff (%)              -1.708025         1.055825           -1.618           0.106
# L12.Currency in Circulation / Total Assets Diff         9.780171         3.432492            2.849           0.004
# L12.Unemployment Loss Diff                              0.030378         0.091349            0.333           0.739
# L12.Inflation Loss Diff                                -0.000062         0.372077           -0.000           1.000
# ==================================================================================================================
#
# Results for equation Inflation Loss Diff
# ==================================================================================================================
#                                                      coefficient       std. error           t-stat            prob
# ------------------------------------------------------------------------------------------------------------------
# const                                                   0.034178         0.018505            1.847           0.065
# L1.Effective Federal Funds Rate Diff (%)                1.120052         0.164394            6.813           0.000
# L1.Currency in Circulation / Total Assets Diff         -2.971024         1.389695           -2.138           0.033
# L1.Unemployment Loss Diff                               0.015512         0.029000            0.535           0.593
# L1.Inflation Loss Diff                                  0.955823         0.103458            9.239           0.000
# L2.Effective Federal Funds Rate Diff (%)               -1.577559         0.311247           -5.069           0.000
# L2.Currency in Circulation / Total Assets Diff          3.654997         2.269023            1.611           0.107
# L2.Unemployment Loss Diff                              -0.061157         0.043380           -1.410           0.159
# L2.Inflation Loss Diff                                 -0.118785         0.141165           -0.841           0.400
# L3.Effective Federal Funds Rate Diff (%)                0.107473         0.473046            0.227           0.820
# L3.Currency in Circulation / Total Assets Diff          2.601421         2.336744            1.113           0.266
# L3.Unemployment Loss Diff                               0.027954         0.043759            0.639           0.523
# L3.Inflation Loss Diff                                  0.056161         0.150434            0.373           0.709
# L4.Effective Federal Funds Rate Diff (%)                0.024117         0.514203            0.047           0.963
# L4.Currency in Circulation / Total Assets Diff         -2.985901         1.873659           -1.594           0.111
# L4.Unemployment Loss Diff                               0.030113         0.044424            0.678           0.498
# L4.Inflation Loss Diff                                  0.165027         0.155901            1.059           0.290
# L5.Effective Federal Funds Rate Diff (%)                0.385663         0.514813            0.749           0.454
# L5.Currency in Circulation / Total Assets Diff          1.815423         1.643686            1.104           0.269
# L5.Unemployment Loss Diff                              -0.009381         0.044846           -0.209           0.834
# L5.Inflation Loss Diff                                 -0.193578         0.155694           -1.243           0.214
# L6.Effective Federal Funds Rate Diff (%)                0.281491         0.525948            0.535           0.593
# L6.Currency in Circulation / Total Assets Diff         -3.620432         1.619500           -2.236           0.025
# L6.Unemployment Loss Diff                              -0.021381         0.045801           -0.467           0.641
# L6.Inflation Loss Diff                                 -0.142298         0.153339           -0.928           0.353
# L7.Effective Federal Funds Rate Diff (%)                0.025957         0.530803            0.049           0.961
# L7.Currency in Circulation / Total Assets Diff          1.525640         1.671185            0.913           0.361
# L7.Unemployment Loss Diff                               0.032179         0.040248            0.800           0.424
# L7.Inflation Loss Diff                                 -0.149429         0.143903           -1.038           0.299
# L8.Effective Federal Funds Rate Diff (%)                0.087056         0.465595            0.187           0.852
# L8.Currency in Circulation / Total Assets Diff         -1.416115         1.498648           -0.945           0.345
# L8.Unemployment Loss Diff                              -0.019776         0.041516           -0.476           0.634
# L8.Inflation Loss Diff                                  0.178192         0.144580            1.232           0.218
# L9.Effective Federal Funds Rate Diff (%)               -0.355098         0.428325           -0.829           0.407
# L9.Currency in Circulation / Total Assets Diff          0.969360         1.473470            0.658           0.511
# L9.Unemployment Loss Diff                              -0.010251         0.042940           -0.239           0.811
# L9.Inflation Loss Diff                                  0.047749         0.148002            0.323           0.747
# L10.Effective Federal Funds Rate Diff (%)              -0.374335         0.563594           -0.664           0.507
# L10.Currency in Circulation / Total Assets Diff         1.087149         1.593091            0.682           0.495
# L10.Unemployment Loss Diff                             -0.068574         0.037781           -1.815           0.070
# L10.Inflation Loss Diff                                -0.132817         0.149490           -0.888           0.374
# L11.Effective Federal Funds Rate Diff (%)              -0.387026         0.538196           -0.719           0.472
# L11.Currency in Circulation / Total Assets Diff         0.844976         1.513835            0.558           0.577
# L11.Unemployment Loss Diff                              0.094954         0.029968            3.169           0.002
# L11.Inflation Loss Diff                                 0.014067         0.150538            0.093           0.926
# L12.Effective Federal Funds Rate Diff (%)               0.704515         0.293753            2.398           0.016
# L12.Currency in Circulation / Total Assets Diff        -1.087316         0.954991           -1.139           0.255
# L12.Unemployment Loss Diff                              0.026688         0.025415            1.050           0.294
# L12.Inflation Loss Diff                                -0.028497         0.103520           -0.275           0.783
# ==================================================================================================================
#
# Correlation matrix of residuals
#                                                Effective Federal Funds Rate Diff (%)  Currency in Circulation / Total Assets Diff  Unemployment Loss Diff  Inflation Loss Diff
# Effective Federal Funds Rate Diff (%)                                       1.000000                                     0.502842               -0.238532             0.194894
# Currency in Circulation / Total Assets Diff                                 0.502842                                     1.000000               -0.118084             0.030786
# Unemployment Loss Diff                                                     -0.238532                                    -0.118084                1.000000            -0.212629
# Inflation Loss Diff                                                         0.194894                                     0.030786               -0.212629             1.000000

# %%
diffs = [" Diff"]
for diff in diffs:
    plot_vars_dct = {0: ["Linear Loss" + diff,
                         "Effective Federal Funds Rate" +diff + " (%)",
                         "Currency in Circulation / Total Assets" + diff],
#                      1:["Currency in Circulation Growth Rate" +diff + " (%)",
#                         "Linear Loss" + diff,
#                         "Effective Federal Funds Rate" +diff + " (%)",
#                         "Total Assets Growth Rate" +diff + " (%)"],
                     2:["Unemployment Loss" + diff,
                        "Inflation Loss" + diff,
                        "Effective Federal Funds Rate" +diff + " (%)",
                        "Currency in Circulation / Total Assets" + diff],
#                      3:["Currency in Circulation Growth Rate" +diff + " (%)",
#                         "Unemployment Loss" + diff,
#                         "Inflation Loss" + diff,
#                         "Effective Federal Funds Rate" +diff + " (%)",
#                         "Total Assets Growth Rate" +diff + " (%)"],
    }
    for key, val in plot_vars_dct.items():
        fig, ax = plt.subplots(figsize = (12, 8))
        axes= {}
        i = 0
        for key in val:
            axes[key] = ax.twinx() if i > 0 else ax
            a = axes[key]
            a.set_yticks([])
            data.loc["2009-07-31":][key].plot.line(ax = a, 
                                  c = "C" + str(i),
                                 legend = False)

            i += 1
        plt.legend()
#         for x in val:
#             for y in val:
#                 if x != y:
#                     for z in val:
#                         if x != z and y != z:
#                             fig, ax = plt.subplots(figsize = (12, 8))
#                             data.loc["2008-10-31":].plot.scatter(x = x, y = y, c = z, 
#                                               cmap= "viridis",ax = ax)
#                             plt.show()
#                             plt.close()

# %%
from pgmpy.estimators import PC
from pgmpy.base import DAG

keys = dag_df.keys()
c = PC(dag_df.dropna())
max_cond_vars = len(keys) - 2

sig = 0.05
variant = "parallel"
ci_test = "pearsonr"
model = c.estimate(return_type = "dag",variant= variant, 
                   significance_level = sig, 
                   max_cond_vars = max_cond_vars, ci_test = ci_test)

edges = model.edges()
pcorr = dag_df.pcorr()
weights = {}
for edge in edges:
    print(edge, ":",pcorr[edge[0]].loc[edge[1]])
skel, sep_sets = c.build_skeleton(variant = variant, ci_test = ci_test, significance_level = 0.01, 
                   max_cond_vars = max_cond_vars)
sep_sets
# Out:
# Working for n conditional variables: 2: 100%|████████████████████████████████████████████| 2/2 [00:00<00:00, 16.74it/s]C:\Users\JLCat\anaconda3\lib\site-packages\pgmpy\estimators\PC.py:369: UserWarning: Reached maximum number of allowed conditional variables. Exiting
#   warn("Reached maximum number of allowed conditional variables. Exiting")
# Working for n conditional variables: 2: 100%|████████████████████████████████████████████| 2/2 [00:00<00:00, 15.45it/s]
# Working for n conditional variables: 2: 100%|████████████████████████████████████████████| 2/2 [00:00<00:00, 14.22it/s]
# ('Effective\nFederal\nFunds\nRate\n(%)', 'Unemployment\nLoss\nSq') : -0.39326293426608566
# ('Currency\nin\nCirculation\n/\nTotal\nAssets', 'Effective\nFederal\nFunds\nRate\n(%)') : 0.7549008118196924
# ('Inflation\nLoss\nSq', 'Currency\nin\nCirculation\n/\nTotal\nAssets') : 0.28218990767740326
# {frozenset({'Inflation\nLoss\nSq',
#             'Unemployment\nLoss\nSq'}): ('Effective\nFederal\nFunds\nRate\n(%)',),
#  frozenset({'Currency\nin\nCirculation\n/\nTotal\nAssets',
#             'Unemployment\nLoss\nSq'}): ('Effective\nFederal\nFunds\nRate\n(%)',),
#  frozenset({'Effective\nFederal\nFunds\nRate\n(%)',
#             'Inflation\nLoss\nSq'}): ('Currency\nin\nCirculation\n/\nTotal\nAssets',)}

# %%
import matplotlib.pyplot as plt
from matplotlib.patches import ArrowStyle
import networkx as nx
plt.rcParams.update({"font.size":20})

def graph_DAG(edges, df, title = ""):
    pcorr = df.pcorr()
    graph = nx.DiGraph()
    edge_labels = {}
    for edge in edges:
        edge_labels[edge] = str(round(pcorr[edge[0]].loc[edge[1]],2))
        
    graph.add_edges_from(edges)
    color_map = ["C0" for g in graph]

    fig, ax = plt.subplots(figsize = (20,20))
    graph.nodes()
    plt.tight_layout()
    pos = nx.spring_layout(graph)#, k = 5/(len(sig_corr.keys())**.5))

    plt.title(title, fontsize = 30)
    nx.draw_networkx(graph, pos, node_color=color_map, node_size = 1200,
                     with_labels=True,  arrows=True,
                     #font_color = "white",
                     font_size = 26, alpha = 1,
                     width = 1, edge_color = "C1",
                     arrowstyle=ArrowStyle("Fancy, head_length=3, head_width=1.5, tail_width=.1"), ax = ax)
    nx.draw_networkx_edge_labels(graph,pos,
                                 edge_labels=edge_labels,
                                 font_color='green',
                                 font_size=20)

graph_DAG(edges, dag_df)

# %%
from pgmpy.estimators import PC
from pgmpy.base import DAG

keys = dag_df.keys()
c = PC(dag_df.dropna())
max_cond_vars = len(keys) - 2

variant = "parallel"
ci_test = "pearsonr"
model = c.estimate(return_type = "dag",variant= variant, 
                   significance_level = sig, 
                   max_cond_vars = max_cond_vars, ci_test = ci_test)

edges = model.edges()
pcorr = dag_df.pcorr()
weights = {}
for edge in edges:
    print(edge, ":",pcorr[edge[0]].loc[edge[1]])
skel, sep_sets = c.build_skeleton(variant = variant, ci_test = ci_test, significance_level = 0.01, 
                   max_cond_vars = max_cond_vars)
sep_sets
# Out:
# Working for n conditional variables: 2: 100%|████████████████████████████████████████████| 2/2 [00:00<00:00, 16.16it/s]C:\Users\JLCat\anaconda3\lib\site-packages\pgmpy\estimators\PC.py:369: UserWarning: Reached maximum number of allowed conditional variables. Exiting
#   warn("Reached maximum number of allowed conditional variables. Exiting")
# Working for n conditional variables: 2: 100%|████████████████████████████████████████████| 2/2 [00:00<00:00, 14.95it/s]
# Working for n conditional variables: 2: 100%|████████████████████████████████████████████| 2/2 [00:00<00:00, 14.64it/s]
# ('Effective\nFederal\nFunds\nRate\n(%)', 'Unemployment\nLoss\nSq') : -0.39326293426608566
# ('Currency\nin\nCirculation\n/\nTotal\nAssets', 'Effective\nFederal\nFunds\nRate\n(%)') : 0.7549008118196924
# ('Inflation\nLoss\nSq', 'Currency\nin\nCirculation\n/\nTotal\nAssets') : 0.28218990767740326
# {frozenset({'Inflation\nLoss\nSq',
#             'Unemployment\nLoss\nSq'}): ('Effective\nFederal\nFunds\nRate\n(%)',),
#  frozenset({'Currency\nin\nCirculation\n/\nTotal\nAssets',
#             'Unemployment\nLoss\nSq'}): ('Effective\nFederal\nFunds\nRate\n(%)',),
#  frozenset({'Effective\nFederal\nFunds\nRate\n(%)',
#             'Inflation\nLoss\nSq'}): ('Currency\nin\nCirculation\n/\nTotal\nAssets',)}

# %%
graph_DAG(edges, dag_df)

# %%
from pgmpy.estimators import PC
from pgmpy.base import DAG

keys = dag_df.keys()
c = PC(dag_df.dropna())
max_cond_vars = len(keys) - 2

variant = "parallel"
ci_test = "pearsonr"
model = c.estimate(return_type = "dag",variant= variant, 
                   significance_level = sig, 
                   max_cond_vars = max_cond_vars, ci_test = ci_test)

edges = model.edges()
pcorr = dag_df.pcorr()
weights = {}
for edge in edges:
    print(edge, ":",pcorr[edge[0]].loc[edge[1]])
skel, sep_sets = c.build_skeleton(variant = variant, ci_test = ci_test, significance_level = 0.01, 
                   max_cond_vars = max_cond_vars)
sep_sets

# %%
graph_DAG(edges, dag_df)

# %%
from pgmpy.estimators import PC
from pgmpy.base import DAG

keys = dag_df.keys()
c = PC(dag_df.dropna())
max_cond_vars = len(keys) - 2

variant = "parallel"
ci_test = "pearsonr"
model = c.estimate(return_type = "dag",variant= variant, 
                   significance_level = sig, 
                   max_cond_vars = max_cond_vars, ci_test = ci_test)

edges = model.edges()
pcorr = dag_df.pcorr()
weights = {}
for edge in edges:
    print(edge, ":",pcorr[edge[0]].loc[edge[1]])
skel, sep_sets = c.build_skeleton(variant = variant, ci_test = ci_test, significance_level = 0.01, 
                   max_cond_vars = max_cond_vars)
sep_sets

# %%
for key in sep_sets:
    print(list(sep_sets[key]))

# %%
graph_DAG(edges, dag_df)

# %%
import matplotlib.pyplot as plt
from matplotlib.patches import ArrowStyle
import networkx as nx
plt.rcParams.update({"font.size":20})

def graph_DAG(edges, df,sep_sets, title = ""):
    graph = nx.DiGraph()
    edge_labels = {}
    pcorr = df.pcorr()
    for edge in sep_sets:
        sep_set = list(sep_sets[edge])
        key = list(edge)
#        pcorr = df[key + sep_set].pcorr()
        edge_labels[edge] = str(round(pcorr[key[0]].loc[key[1]],2))
    print(edge_labels)
    graph.add_edges_from(sep_sets.keys())
    color_map = ["C0" for g in graph]

    fig, ax = plt.subplots(figsize = (20,20))
    graph.nodes()
    plt.tight_layout()
    pos = nx.spring_layout(graph)#, k = 5/(len(sig_corr.keys())**.5))

    plt.title(title, fontsize = 30)
    nx.draw_networkx(graph, pos, node_color=color_map, node_size = 1200,
                     with_labels=True,  arrows=True,
                     #font_color = "white",
                     font_size = 26, alpha = 1,
                     width = 1, edge_color = "C1",
                     arrowstyle=ArrowStyle("Fancy, head_length=3, head_width=1.5, tail_width=.1"), ax = ax)
    nx.draw_networkx_edge_labels(graph,pos,
                                 edge_labels=edge_labels,
                                 font_color='green',
                                 font_size=20)

graph_DAG(edges, dag_df, sep_sets)

# %%
dag_df

# %%
figsize = (20,12)
fig,ax = plt.subplots(figsize = figsize)

ax2 = ax.twinx()
ax3 = ax.twinx()
data[["Currency in Circulation / Total Assets"]].plot(legend = False, 
                                                      linewidth = 5, 
                                                      alpha = .8,
                                                      ax = ax)
data[["Effective Federal Funds Rate (%)"]].plot(legend = False, 
                                                      linewidth = 5, 
                                                      alpha = .8,
                                                      ax = ax2,
                                                        c = "C1")
data[["Linear Loss"]].iloc[:-1].plot(legend = False, 
                                                      linewidth = 5, 
                                                      alpha = .1,
                                                      ax = ax3,
                                                        c = "k")

ax.set_yticklabels([str(int(val * 100)) + "%" for val in ax.get_yticks()], c = "C0")
ax2.set_yticklabels([str(int(val)) + "%" for val in ax2.get_yticks()], c = "C1")
ax3.set_yticklabels(ax3.get_yticks(), alpha = .2, c = "k")
ax3.set_yticks([])

ax3.axhline(0, c = "k", alpha = .1, linewidth = 5, ls = "--")

plt.axvline(datetime.datetime(2008,10,1), c = "k", ls = "--", alpha = .9)
ax.text(datetime.datetime(2013,3,1), .42, "Currency in Circulation\n/  \nTotal Assets", fontsize = 25, c = "C0", 
        ha = "center")
ax.text(datetime.datetime(2018,5,1), .58, "Effective\nFederal\nFunds\nRate", fontsize = 25, c = "C1", 
        ha = "center")
ax.text(datetime.datetime(2014,6,1), .78, "Linear\nLoss\nFunction", fontsize = 25, c = "k", alpha = .3, 
        ha = "center")
ax.text(datetime.datetime(2002,10,1), .955, "0", fontsize = 30, c = "k", alpha = .3, 
        ha = "right")
ax.text(datetime.datetime(2022,1,1), .955, "0 ", fontsize = 30, c = "k", alpha = .3, 
        ha = "right")

# %%
fig, ax = plt.subplots(figsize = (30,15))
data[["Linear Loss Diff", "Total Assets Growth Rate (%)"]].plot.scatter(x = "Linear Loss Diff", y = "Total Assets Growth Rate (%)", ax = ax)
plt.xticks(rotation=90)

# %%
fig, ax = plt.subplots(figsize = (30,15))
data.iloc[:-1].plot.scatter(x = "Linear Loss", y = "Currency in Circulation / Total Assets", ax = ax)
plt.xticks(rotation=90)
