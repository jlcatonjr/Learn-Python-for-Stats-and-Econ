# %%
# %matplotlib notebook
import ipywidgets as ipw 
from IPython.display import clear_output
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random
import time
class livePlot(): 
    def __init__(self, width = 10, length = 10, patch_dim = 10):
        
        
        self.max_val = 50
        plt.rcParams["font.size"] = 20
#        self.fig, self.ax = plt.subplots(1, figsize = (15, 15))
        # use ax.imshow() to create a heatmap of correlation values  
        # seismic mapping shows negative values as blue and positive values as red  
        self.data= pd.DataFrame({i:{j:random.randint(0,self.max_val) for j in range(width)} for i in range(length)})
        self.fig, self.ax = plt.subplots(figsize = (10, 10))
        
        self.im = self.ax.imshow(self.data, norm = plt.cm.colors.Normalize(0,self.max_val), cmap = "Blues")  

        
    
    def update(self,empty_x, empty_y):
        def reset_map():
            for key in self.data:
                self.data[key] = self.max_val
        def increment_patches():
            for key, val in self.data.items():
                for i in range(len(val)):
                    if val[i] < self.max_val:
                        self.data[key].iloc[i] += 1

        self.data[empty_x].loc[empty_y] = 0
        increment_patches()
        self.im.set_data(self.data)
            
        #self.im = self.ax.imshow(self.data, norm = plt.cm.colors.Normalize(0,self.max_val), cmap = "Reds")  

#            reset_map()
#            for i in range(num_empty_patches):
#                x = random.choice(list(self.data.keys()))
#                y = random.choice(list(self.data[x].index))
#                self.data[x].loc[y] = 0
#                increment_patches()
#                self.im.set_data(self.data)
#                self.fig.canvas.flush_events()

#            while self.data.min().min() < self.max_val:
#                increment_patches()
#                self.im.set_data(self.data)

plot = livePlot()
ipw.interact(plot.update,
             empty_x = ipw.widgets.IntSlider(value = 0,
                                             min = 0,
                                             max = len(plot.data.keys())-1,
                                             step = 1),
             empty_y = ipw.widgets.IntSlider(value = 0,
                                             min = 0,
                                             max = len(plot.data.index)-1,
                                             step = 1))
# Out:
# <img src="data:image/png;base64,..." width="1665.6">
# interactive(children=(IntSlider(value=0, description='empty_x', max=9), IntSlider(value=0, description='empty_…
# <function ipywidgets.widgets.interaction._InteractFactory.__call__.<locals>.<lambda>(*args, **kwargs)>
