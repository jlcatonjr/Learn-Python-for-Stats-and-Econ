# %%
#multiIndex.py
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# index_col = [0,2] will select  countrycode as the primary index and year as 
# the secondary index
data = pd.read_excel("mpd2018.xlsx", 
                     sheet_name = "Full data", 
                     index_col = [0,2])
# Out:
# year
# 1           NaN
# 1000        NaN
# 1500        NaN
# 1600        NaN
# 1650      897.0
# 1700        NaN
# 1720     1375.0
# 1775     1883.0
# 1800     1980.0
# 1801     2017.0
# 1802     2050.0
# 1803     2015.0
# 1804     2014.0
# 1805     2056.0
# 1806     2094.0
# 1807     2114.0
# 1808     1965.0
# 1809     2062.0
# 1810     2120.0
# 1811     2163.0
# 1812     2125.0
# 1813     2149.0
# 1814     2190.0
# 1815     2180.0
# 1816     2092.0
# 1817     2091.0
# 1818     2097.0
# 1819     2092.0
# 1820     2080.0
# 1821     2113.0
#          ...
# 1987    34730.0
# 1988    35865.0
# 1989    36757.0
# 1990    36982.0
# 1991    36464.0
# 1992    37241.0
# 1993    37762.0
# 1994    38808.0
# 1995    39391.0
# 1996    40414.0
# 1997    41723.0
# 1998    43073.0
# 1999    44576.0
# 2000    45887.0
# 2001    45878.0
# 2002    46267.0
# 2003    47158.0
# 2004    48493.0
# 2005    49655.0
# 2006    50490.0
# 2007    50902.0
# 2008    50276.0
# 2009    48453.0
# 2010    49267.0
# ...

# %%
# to gather all of the years, we group observations by year, 
# which will remove the other column of the multiindex 
years = data.groupby("year").mean().index
data[data.index.get_level_values("countrycode") == "USA"]
countries = ["USA", "CAN", "MEX", "UK","FRA"]

fig, ax = plt.subplots(figsize = (30, 16))
for country in countries:
    data.loc[country]["cgdppc"].plot.line(ax = ax, label = country, legend = True)
plt.xlim([1825,years[-1]])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'UK'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-18-46ea3acd2160> in <module>
# ...

# %%
countries = data.groupby("countrycode").mean().index

# %%
# pairs of countries to compare in plots
pairs = [("CAN", "FIN"), ("FRA", "DEU"), ("GBR", "NLD")]
linestyles = ["-", ":"]

for pair in pairs:  
    fig, ax = plt.subplots(figsize=(16,8))  
    for i in range(len(pair)):  
        country = pair[i]  
        linestyle = linestyles[i]  
        data.loc[country,:]["cgdppc"].dropna(
        ).plot.line(ax = ax,  
               label = country, linestyle = linestyle)  
      
    plt.rcParams.update({"legeplt.xlim([1825, max(years)])nd.fontsize": 25, "legend.handlelength": 2})  
    plt.rcParams.update({"font.size": 25})  
    plt.ylabel(
        "$Real$ $GDP$ $Per$ $Capita$\n2011 U.S. Dollars",
        fontsize=36)  
    plt.legend()  
    plt.show()  
    plt.close()
